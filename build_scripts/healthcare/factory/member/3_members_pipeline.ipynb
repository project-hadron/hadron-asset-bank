# %%
# %run ../base_setup.ipynb
# Out:
# Foundation: 2.11.012
# Transition: 2.11.014
# Engines   : 2.03.027
# Behavioral: 2.06.033

# %%
sample_size = 10000
seed = None

# %% [markdown]
# -------------------------
# ## Synthetic Builder

# %%
builder = SyntheticBuilder.from_env('members')

# %% [markdown]
# ### Run the Pipeline  save the Schema and show the Canonical Report

# %%
# set the version
builder.set_version(VERSION)

# run the pipeline
builder.run_synthetic_pipeline(size=sample_size)

# report
builder.canonical_report(builder.load_synthetic_canonical(), stylise=True)
# Out:
# <style  type="text/css" >
#     #T_83631_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_83631_ .row_heading, .blank {
#           display: none;;
#     }#T_83631_row0_col0,#T_83631_row1_col0,#T_83631_row2_col0,#T_83631_row3_col0,#T_83631_row4_col0,#T_83631_row5_col0,#T_83631_row6_col0,#T_83631_row7_col0,#T_83631_row8_col0,#T_83631_row9_col0,#T_83631_row10_col0,#T_83631_row11_col0,#T_83631_row12_col0,#T_83631_row13_col0,#T_83631_row14_col0,#T_83631_row15_col0,#T_83631_row16_col0,#T_83631_row17_col0,#T_83631_row18_col0,#T_83631_row19_col0,#T_83631_row20_col0,#T_83631_row21_col0,#T_83631_row22_col0,#T_83631_row23_col0,#T_83631_row24_col0,#T_83631_row25_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_83631_row0_col2,#T_83631_row0_col3,#T_83631_row0_col6,#T_83631_row1_col2,#T_83631_row1_col3,#T_83631_row2_col2,#T_83631_row2_col3,#T_83631_row2_col4,#T_83631_row3_col2,#T_83631_row3_col3,#T_83631_row3_col6,#T_83631_row4_col2,#T_83631_row4_col3,#T_83631_row4_col6,#T_83631_row5_col2,#T_83631_row5_col3,#T_83631_row5_col6,#T_83631_row6_col2,#T_83631_row7_col2,#T_83631_row7_col3,#T_83631_row7_col6,#T_83631_row8_col2,#T_83631_row8_col3,#T_83631_row8_col6,#T_83631_row9_col2,#T_83631_row9_col3,#T_83631_row9_col6,#T_83631_row10_col2,#T_83631_row10_col3,#T_83631_row10_col6,#T_83631_row11_col2,#T_83631_row11_col3,#T_83631_row11_col4,#T_83631_row12_col2,#T_83631_row13_col2,#T_83631_row14_col2,#T_83631_row14_col4,#T_83631_row15_col2,#T_83631_row15_col3,#T_83631_row15_col6,#T_83631_row16_col2,#T_83631_row16_col4,#T_83631_row17_col2,#T_83631_row17_col3,#T_83631_row17_col4,#T_83631_row18_col2,#T_83631_row18_col3,#T_83631_row18_col6,#T_83631_row19_col2,#T_83631_row19_col3,#T_83631_row19_col6,#T_83631_row20_col2,#T_83631_row20_col3,#T_83631_row20_col6,#T_83631_row21_col2,#T_83631_row21_col3,#T_83631_row21_col4,#T_83631_row22_col2,#T_83631_row22_col3,#T_83631_row22_col4,#T_83631_row23_col2,#T_83631_row23_col3,#T_83631_row24_col2,#T_83631_row24_col3,#T_83631_row25_col2,#T_83631_row25_col3,#T_83631_row25_col6{
#             color:  black;
#         }#T_83631_row0_col4,#T_83631_row7_col4,#T_83631_row8_col4,#T_83631_row9_col4,#T_83631_row10_col4,#T_83631_row12_col4,#T_83631_row15_col4,#T_83631_row18_col4,#T_83631_row19_col4,#T_83631_row20_col4,#T_83631_row25_col4{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_83631_row1_col1,#T_83631_row5_col1,#T_83631_row6_col1,#T_83631_row12_col1,#T_83631_row13_col1,#T_83631_row14_col1,#T_83631_row18_col1,#T_83631_row21_col1{
#             color:  #0f398a;
#         }#T_83631_row1_col4,#T_83631_row4_col4,#T_83631_row5_col4{
#             background-color:  #fb7858;
#             color:  black;
#         }#T_83631_row1_col6{
#             background-color:  #f0f9ed;
#             color:  black;
#         }#T_83631_row2_col6,#T_83631_row22_col6{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_83631_row3_col4,#T_83631_row12_col3{
#             background-color:  #f7593f;
#             color:  white;
#         }#T_83631_row6_col3,#T_83631_row6_col4{
#             background-color:  #fc9576;
#             color:  black;
#         }#T_83631_row6_col6,#T_83631_row11_col6,#T_83631_row12_col6,#T_83631_row13_col6,#T_83631_row14_col6,#T_83631_row16_col6,#T_83631_row17_col6,#T_83631_row21_col6{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_83631_row13_col3,#T_83631_row13_col4{
#             background-color:  #fcb499;
#             color:  black;
#         }#T_83631_row14_col3,#T_83631_row16_col3{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_83631_row20_col1{
#             color:  #2f0f8a;
#         }#T_83631_row23_col4,#T_83631_row24_col4{
#             background-color:  #fdcdb9;
#             color:  black;
#         }#T_83631_row23_col6,#T_83631_row24_col6{
#             background-color:  #c1e6ba;
#             color:  black;
#         }</style><table id="T_83631_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (26)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83631_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_83631_row0_col0" class="data row0 col0" >address</td>
#                         <td id="T_83631_row0_col1" class="data row0 col1" >object</td>
#                         <td id="T_83631_row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_83631_row0_col3" class="data row0 col3" >0.0%</td>
#                                 <td id="T_83631_row0_col5" class="data row0 col5" >10000</td>
#                         <td id="T_83631_row0_col6" class="data row0 col6" >10000</td>
#                         <td id="T_83631_row0_col7" class="data row0 col7" >Sample: 54083 Skog Crescent | 8859 Suncrest Grove | 7896 Oak Branch | 76141 Berry Hill Creek | 55542...</td>
#             </tr>
#             <tr>
#                         <th id="T_83631_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_83631_row1_col0" class="data row1 col0" >age</td>
#                         <td id="T_83631_row1_col1" class="data row1 col1" >int64</td>
#                         <td id="T_83631_row1_col2" class="data row1 col2" >0.0%</td>
#                         <td id="T_83631_row1_col3" class="data row1 col3" >2.7%</td>
#                                 <td id="T_83631_row1_col5" class="data row1 col5" >10000</td>
#                         <td id="T_83631_row1_col6" class="data row1 col6" >74</td>
#                         <td id="T_83631_row1_col7" class="data row1 col7" >max=97 | min=18 | mean=45.5 | dominant=42</td>
#             </tr>
#             <tr>
#                         <th id="T_83631_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_83631_row2_col0" class="data row2 col0" >channel_pref</td>
#                         <td id="T_83631_row2_col1" class="data row2 col1" >object</td>
#                         <td id="T_83631_row2_col2" class="data row2 col2" >0.0%</td>
#                         <td id="T_83631_row2_col3" class="data row2 col3" >32.9%</td>
#                                 <td id="T_83631_row2_col5" class="data row2 col5" >10000</td>
#                         <td id="T_83631_row2_col6" class="data row2 col6" >6</td>
#                         <td id="T_83631_row2_col7" class="data row2 col7" >Sample: SydneyCare | Phone | Email | SMS | RCP</td>
#             </tr>
#             <tr>
#                         <th id="T_83631_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_83631_row3_col0" class="data row3 col0" >city</td>
#                         <td id="T_83631_row3_col1" class="data row3 col1" >object</td>
#                         <td id="T_83631_row3_col2" class="data row3 col2" >0.0%</td>
#                         <td id="T_83631_row3_col3" class="data row3 col3" >2.0%</td>
#                                 <td id="T_83631_row3_col5" class="data row3 col5" >10000</td>
#                         <td id="T_83631_row3_col6" class="data row3 col6" >5583</td>
#                         <td id="T_83631_row3_col7" class="data row3 col7" >Sample: New York | Los Angeles | Columbus | Sacramento | San Diego</td>
#             </tr>
#             <tr>
#                         <th id="T_83631_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_83631_row4_col0" class="data row4 col0" >county</td>
#                         <td id="T_83631_row4_col1" class="data row4 col1" >object</td>
#                         <td

# %% [markdown]
# ### Save Reports

# %%
builder.save_report_canonical(report_connector_name=builder.REPORT_INTENT, report=builder.report_intent(stylise=False))
builder.save_report_canonical(report_connector_name=builder.REPORT_CATALOG, report=builder.report_column_catalog(stylise=False))

# %% [markdown]
# -------------------------
# ## Members Transition

# %%
tr = Transition.from_env('members')

# %%
# set the version
tr.set_version(VERSION)

# run the pipeline
tr.run_transition_pipeline()

# report
tr.canonical_report(tr.load_clean_canonical(), stylise=True)
# Out:
# <style  type="text/css" >
#     #T_18d50_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_18d50_ .row_heading, .blank {
#           display: none;;
#     }#T_18d50_row0_col0,#T_18d50_row1_col0,#T_18d50_row2_col0,#T_18d50_row3_col0,#T_18d50_row4_col0,#T_18d50_row5_col0,#T_18d50_row6_col0,#T_18d50_row7_col0,#T_18d50_row8_col0,#T_18d50_row9_col0,#T_18d50_row10_col0,#T_18d50_row11_col0,#T_18d50_row12_col0,#T_18d50_row13_col0,#T_18d50_row14_col0,#T_18d50_row15_col0,#T_18d50_row16_col0,#T_18d50_row17_col0,#T_18d50_row18_col0,#T_18d50_row19_col0,#T_18d50_row20_col0,#T_18d50_row21_col0,#T_18d50_row22_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_18d50_row0_col1,#T_18d50_row2_col1,#T_18d50_row3_col1,#T_18d50_row6_col1,#T_18d50_row7_col1,#T_18d50_row8_col1,#T_18d50_row17_col1,#T_18d50_row20_col1{
#             color:  #761d38;
#         }#T_18d50_row0_col2,#T_18d50_row0_col3,#T_18d50_row0_col6,#T_18d50_row1_col2,#T_18d50_row1_col3,#T_18d50_row1_col4,#T_18d50_row2_col2,#T_18d50_row2_col3,#T_18d50_row2_col6,#T_18d50_row3_col2,#T_18d50_row3_col3,#T_18d50_row3_col6,#T_18d50_row4_col2,#T_18d50_row5_col2,#T_18d50_row5_col3,#T_18d50_row5_col6,#T_18d50_row6_col2,#T_18d50_row6_col3,#T_18d50_row6_col6,#T_18d50_row7_col2,#T_18d50_row7_col3,#T_18d50_row7_col6,#T_18d50_row8_col2,#T_18d50_row8_col3,#T_18d50_row8_col6,#T_18d50_row9_col2,#T_18d50_row9_col3,#T_18d50_row9_col4,#T_18d50_row10_col2,#T_18d50_row11_col2,#T_18d50_row12_col2,#T_18d50_row12_col4,#T_18d50_row13_col2,#T_18d50_row13_col3,#T_18d50_row13_col6,#T_18d50_row14_col2,#T_18d50_row14_col4,#T_18d50_row15_col2,#T_18d50_row15_col3,#T_18d50_row15_col4,#T_18d50_row16_col2,#T_18d50_row16_col3,#T_18d50_row16_col6,#T_18d50_row17_col2,#T_18d50_row17_col3,#T_18d50_row17_col6,#T_18d50_row18_col2,#T_18d50_row18_col3,#T_18d50_row18_col6,#T_18d50_row19_col2,#T_18d50_row19_col3,#T_18d50_row19_col4,#T_18d50_row20_col2,#T_18d50_row20_col3,#T_18d50_row21_col2,#T_18d50_row21_col3,#T_18d50_row22_col2,#T_18d50_row22_col3,#T_18d50_row22_col6{
#             color:  black;
#         }#T_18d50_row0_col4,#T_18d50_row5_col4,#T_18d50_row6_col4,#T_18d50_row7_col4,#T_18d50_row8_col4,#T_18d50_row10_col4,#T_18d50_row13_col4,#T_18d50_row16_col4,#T_18d50_row17_col4,#T_18d50_row18_col4,#T_18d50_row22_col4{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_18d50_row1_col1,#T_18d50_row9_col1,#T_18d50_row14_col1,#T_18d50_row15_col1,#T_18d50_row19_col1,#T_18d50_row21_col1{
#             color:  #208a0f;
#         }#T_18d50_row1_col6,#T_18d50_row19_col6{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_18d50_row2_col4,#T_18d50_row10_col3{
#             background-color:  #f7593f;
#             color:  white;
#         }#T_18d50_row3_col4{
#             background-color:  #fb7858;
#             color:  black;
#         }#T_18d50_row4_col1,#T_18d50_row10_col1,#T_18d50_row11_col1,#T_18d50_row12_col1{
#             color:  #08488e;
#         }#T_18d50_row4_col3,#T_18d50_row4_col4{
#             background-color:  #fc9576;
#             color:  black;
#         }#T_18d50_row4_col6,#T_18d50_row9_col6,#T_18d50_row10_col6,#T_18d50_row11_col6,#T_18d50_row12_col6,#T_18d50_row14_col6,#T_18d50_row15_col6{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_18d50_row5_col1,#T_18d50_row13_col1{
#             color:  #790f8a;
#         }#T_18d50_row11_col3,#T_18d50_row11_col4{
#             background-color:  #fcb499;
#             color:  black;
#         }#T_18d50_row12_col3,#T_18d50_row14_col3{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_18d50_row16_col1,#T_18d50_row22_col1{
#             color:  #0f398a;
#         }#T_18d50_row18_col1{
#             color:  #2f0f8a;
#         }#T_18d50_row20_col4,#T_18d50_row21_col4{
#             background-color:  #fdcdb9;
#             color:  black;
#         }#T_18d50_row20_col6,#T_18d50_row21_col6{
#             background-color:  #c1e6ba;
#             color:  black;
#         }</style><table id="T_18d50_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (23)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_18d50_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_18d50_row0_col0" class="data row0 col0" >address</td>
#                         <td id="T_18d50_row0_col1" class="data row0 col1" >string</td>
#                         <td id="T_18d50_row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_18d50_row0_col3" class="data row0 col3" >0.0%</td>
#                                 <td id="T_18d50_row0_col5" class="data row0 col5" >10000</td>
#                         <td id="T_18d50_row0_col6" class="data row0 col6" >10000</td>
#                         <td id="T_18d50_row0_col7" class="data row0 col7" >Sample: 54083 Skog Crescent | 8859 Suncrest Grove | 7896 Oak Branch | 76141 Berry Hill Creek | 55542...</td>
#             </tr>
#             <tr>
#                         <th id="T_18d50_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_18d50_row1_col0" class="data row1 col0" >channel_pref</td>
#                         <td id="T_18d50_row1_col1" class="data row1 col1" >category</td>
#                         <td id="T_18d50_row1_col2" class="data row1 col2" >0.0%</td>
#                         <td id="T_18d50_row1_col3" class="data row1 col3" >32.9%</td>
#                                 <td id="T_18d50_row1_col5" class="data row1 col5" >10000</td>
#                         <td id="T_18d50_row1_col6" class="data row1 col6" >6</td>
#                         <td id="T_18d50_row1_col7" class="data row1 col7" >Sample: SydneyCare | Phone | Email | SMS | RCP</td>
#             </tr>
#             <tr>
#                         <th id="T_18d50_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_18d50_row2_col0" class="data row2 col0" >city</td>
#                         <td id="T_18d50_row2_col1" class="data row2 col1" >string</td>
#                         <td id="T_18d50_row2_col2" class="data row2 col2" >0.0%</td>
#                         <td id="T_18d50_row2_col3" class="data row2 col3" >2.0%</td>
#                                 <td id="T_18d50_row2_col5" class="data row2 col5" >10000</td>
#                         <td id="T_18d50_row2_col6" class="data row2 col6" >5583</td>
#                         <td id="T_18d50_row2_col7" class="data row2 col7" >Sample: New York | Los Angeles | Columbus | Sacramento | San Diego</td>
#             </tr>
#             <tr>
#                         <th id="T_18d50_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_18d50_row3_col0" class="data row3 col0" >county</td>
#                         <td id="T_18d50_row3_col1" class="data row3 col1" >string</td>
#                         <td id="T_18d50_row3_col2" class="data row3 col2" >0.0%</td>
#                         <td id="T_18d50_row3_col3" class="data row3 col3" >3.9%</td>
#                                 <td id="T_18d50_row3_col5" class="data row3 col5" >10000</td>
#                         <td id="T_18d50_row3_col6" class="data row3 col6" >738</td>
#                         <td id="T_18d50_row3_col7" class="data row3 col7" >Sample: Los Angeles | Jefferson | New York | Suffolk | Nassau</td>
#             </tr>
#             <tr>
#                         <th id="T_18d50_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_18d50_row4_col0" class="data row4 col0" >do_not_call</td>
#                         <td id=

# %% [markdown]
# ### Save Reports

# %%
tr.save_report_canonical(report_connector_name=tr.REPORT_DICTIONARY, report=tr.canonical_report(tr.load_clean_canonical(), stylise=False))
tr.save_report_canonical(report_connector_name=tr.REPORT_SUMMARY, report=tr.report_quality_summary(stylise=False))
tr.save_report_canonical(report_connector_name=tr.REPORT_PROVENANCE, report=tr.report_provenance(stylise=False))
tr.save_report_canonical(report_connector_name=tr.REPORT_FIELDS, report=tr.report_attributes(tr.load_clean_canonical(), stylise=False))

# %% [markdown]
# -------------------------
# ## Hello World Members Transition

# %%
tr_hw = Transition.from_env('hello_world_members')

# %%
# set the version
tr_hw.set_version(VERSION)

# run the pipeline
tr_hw.run_transition_pipeline()

# report
tr_hw.canonical_report(tr_hw.load_clean_canonical(), stylise=True)
# Out:
# <style  type="text/css" >
#     #T_a054c_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_a054c_ .row_heading, .blank {
#           display: none;;
#     }#T_a054c_row0_col0,#T_a054c_row1_col0,#T_a054c_row2_col0,#T_a054c_row3_col0,#T_a054c_row4_col0,#T_a054c_row5_col0,#T_a054c_row6_col0,#T_a054c_row7_col0,#T_a054c_row8_col0,#T_a054c_row9_col0,#T_a054c_row10_col0,#T_a054c_row11_col0,#T_a054c_row12_col0,#T_a054c_row13_col0,#T_a054c_row14_col0,#T_a054c_row15_col0,#T_a054c_row16_col0,#T_a054c_row17_col0,#T_a054c_row18_col0,#T_a054c_row19_col0,#T_a054c_row20_col0,#T_a054c_row21_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_a054c_row0_col1,#T_a054c_row3_col1,#T_a054c_row4_col1,#T_a054c_row6_col1,#T_a054c_row7_col1,#T_a054c_row16_col1,#T_a054c_row19_col1{
#             color:  #761d38;
#         }#T_a054c_row0_col2,#T_a054c_row0_col3,#T_a054c_row0_col6,#T_a054c_row1_col2,#T_a054c_row1_col3,#T_a054c_row2_col2,#T_a054c_row2_col3,#T_a054c_row2_col4,#T_a054c_row3_col2,#T_a054c_row3_col3,#T_a054c_row3_col6,#T_a054c_row4_col2,#T_a054c_row4_col3,#T_a054c_row4_col6,#T_a054c_row5_col2,#T_a054c_row6_col2,#T_a054c_row6_col3,#T_a054c_row6_col6,#T_a054c_row7_col2,#T_a054c_row7_col3,#T_a054c_row7_col6,#T_a054c_row8_col2,#T_a054c_row8_col3,#T_a054c_row8_col4,#T_a054c_row9_col2,#T_a054c_row10_col2,#T_a054c_row11_col2,#T_a054c_row11_col4,#T_a054c_row12_col2,#T_a054c_row12_col3,#T_a054c_row12_col6,#T_a054c_row13_col2,#T_a054c_row13_col4,#T_a054c_row14_col2,#T_a054c_row14_col3,#T_a054c_row14_col4,#T_a054c_row15_col2,#T_a054c_row15_col3,#T_a054c_row15_col6,#T_a054c_row16_col2,#T_a054c_row16_col3,#T_a054c_row16_col6,#T_a054c_row17_col2,#T_a054c_row17_col3,#T_a054c_row17_col6,#T_a054c_row18_col2,#T_a054c_row18_col3,#T_a054c_row18_col4,#T_a054c_row19_col2,#T_a054c_row19_col3,#T_a054c_row20_col2,#T_a054c_row20_col3,#T_a054c_row21_col2,#T_a054c_row21_col3,#T_a054c_row21_col6{
#             color:  black;
#         }#T_a054c_row0_col4,#T_a054c_row6_col4,#T_a054c_row7_col4,#T_a054c_row9_col4,#T_a054c_row12_col4,#T_a054c_row15_col4,#T_a054c_row16_col4,#T_a054c_row17_col4,#T_a054c_row21_col4{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_a054c_row1_col1,#T_a054c_row15_col1,#T_a054c_row21_col1{
#             color:  #0f398a;
#         }#T_a054c_row1_col4,#T_a054c_row4_col4{
#             background-color:  #fb7858;
#             color:  black;
#         }#T_a054c_row1_col6{
#             background-color:  #f0f9ed;
#             color:  black;
#         }#T_a054c_row2_col1,#T_a054c_row8_col1,#T_a054c_row13_col1,#T_a054c_row14_col1,#T_a054c_row18_col1,#T_a054c_row20_col1{
#             color:  #208a0f;
#         }#T_a054c_row2_col6,#T_a054c_row18_col6{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_a054c_row3_col4,#T_a054c_row9_col3{
#             background-color:  #f7593f;
#             color:  white;
#         }#T_a054c_row5_col1,#T_a054c_row9_col1,#T_a054c_row10_col1,#T_a054c_row11_col1{
#             color:  #08488e;
#         }#T_a054c_row5_col3,#T_a054c_row5_col4{
#             background-color:  #fc9576;
#             color:  black;
#         }#T_a054c_row5_col6,#T_a054c_row8_col6,#T_a054c_row9_col6,#T_a054c_row10_col6,#T_a054c_row11_col6,#T_a054c_row13_col6,#T_a054c_row14_col6{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_a054c_row10_col3,#T_a054c_row10_col4{
#             background-color:  #fcb499;
#             color:  black;
#         }#T_a054c_row11_col3,#T_a054c_row13_col3{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_a054c_row12_col1{
#             color:  #790f8a;
#         }#T_a054c_row17_col1{
#             color:  #2f0f8a;
#         }#T_a054c_row19_col4,#T_a054c_row20_col4{
#             background-color:  #fdcdb9;
#             color:  black;
#         }#T_a054c_row19_col6,#T_a054c_row20_col6{
#             background-color:  #c1e6ba;
#             color:  black;
#         }</style><table id="T_a054c_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (22)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a054c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a054c_row0_col0" class="data row0 col0" >address</td>
#                         <td id="T_a054c_row0_col1" class="data row0 col1" >string</td>
#                         <td id="T_a054c_row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_a054c_row0_col3" class="data row0 col3" >0.0%</td>
#                                 <td id="T_a054c_row0_col5" class="data row0 col5" >10000</td>
#                         <td id="T_a054c_row0_col6" class="data row0 col6" >10000</td>
#                         <td id="T_a054c_row0_col7" class="data row0 col7" >Sample: 54083 Skog Crescent | 8859 Suncrest Grove | 7896 Oak Branch | 76141 Berry Hill Creek | 55542...</td>
#             </tr>
#             <tr>
#                         <th id="T_a054c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a054c_row1_col0" class="data row1 col0" >age</td>
#                         <td id="T_a054c_row1_col1" class="data row1 col1" >int64</td>
#                         <td id="T_a054c_row1_col2" class="data row1 col2" >0.0%</td>
#                         <td id="T_a054c_row1_col3" class="data row1 col3" >2.7%</td>
#                                 <td id="T_a054c_row1_col5" class="data row1 col5" >10000</td>
#                         <td id="T_a054c_row1_col6" class="data row1 col6" >74</td>
#                         <td id="T_a054c_row1_col7" class="data row1 col7" >max=97 | min=18 | mean=45.5 | dominant=42</td>
#             </tr>
#             <tr>
#                         <th id="T_a054c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a054c_row2_col0" class="data row2 col0" >channel_pref</td>
#                         <td id="T_a054c_row2_col1" class="data row2 col1" >category</td>
#                         <td id="T_a054c_row2_col2" class="data row2 col2" >0.0%</td>
#                         <td id="T_a054c_row2_col3" class="data row2 col3" >32.9%</td>
#                                 <td id="T_a054c_row2_col5" class="data row2 col5" >10000</td>
#                         <td id="T_a054c_row2_col6" class="data row2 col6" >6</td>
#                         <td id="T_a054c_row2_col7" class="data row2 col7" >Sample: SydneyCare | Phone | Email | SMS | RCP</td>
#             </tr>
#             <tr>
#                         <th id="T_a054c_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a054c_row3_col0" class="data row3 col0" >city</td>
#                         <td id="T_a054c_row3_col1" class="data row3 col1" >string</td>
#                         <td id="T_a054c_row3_col2" class="data row3 col2" >0.0%</td>
#                         <td id="T_a054c_row3_col3" class="data row3 col3" >2.0%</td>
#                                 <td id="T_a054c_row3_col5" class="data row3 col5" >10000</td>
#                         <td id="T_a054c_row3_col6" class="data row3 col6" >5583</td>
#                         <td id="T_a054c_row3_col7" class="data row3 col7" >Sample: New York | Los Angeles | Columbus | Sacramento | San Diego</td>
#             </tr>
#             <tr>
#                         <th id="T_a054c_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_a054c_row4_col0" class="data row4 col0" >county</td>
#                         <td id="T_a054c_row4_col1" class="data row4 col1" >string</td>

# %% [markdown]
# ### Save Reports

# %%
tr_hw.save_report_canonical(report_connector_name=tr_hw.REPORT_DICTIONARY, report=tr_hw.canonical_report(tr_hw.load_clean_canonical(), stylise=False))
tr_hw.save_report_canonical(report_connector_name=tr_hw.REPORT_SUMMARY, report=tr_hw.report_quality_summary(stylise=False))
tr_hw.save_report_canonical(report_connector_name=tr_hw.REPORT_PROVENANCE, report=tr_hw.report_provenance(stylise=False))
tr_hw.save_report_canonical(report_connector_name=tr_hw.REPORT_FIELDS, report=tr_hw.report_attributes(tr_hw.load_clean_canonical(), stylise=False))

# %%
tr_hw.report_quality_summary()
# Out:
#         report              summary  result
# 0        score          quality_avg     81%
# 1                     usability_avg     96%
# 2               provenance_complete    100%
# 3                    data_described     50%
# 4   data_shape                 rows   10000
# 5                           columns      26
# 6                            memory  5.68MB
# 7    data_type              numeric       4
# 8                          category       8
# 9                          datetime       1
# 10                             bool       5
# 11                           others       8
# 12   usability          mostly_null       0
# 13                     predominance       1
# 14                       correlated       2
# 15                      adjustments       5
# 16        cost                price   $0.00
