# %%
# %run ../base_setup.ipynb
# Out:
# Foundation: 2.11.002
# Transition: 2.11.006
# Engines   : 2.03.022
# Behavioral: 2.06.018

# %%
# task grouping name
task_name = 'members'

# %% [markdown]
# -------------------------
# ## Synthetic Builder

# %%
builder = SyntheticBuilder.from_env(task_name)

# %%
tools = builder.intent_model

# %%
builder.pm.reset_intents()
builder.pm_persist()

# %%
sample_size = 1000
df = pd.DataFrame(index=range(sample_size))

# %% [markdown]
# -----------
# ### Distribution elements

# %%
df = tools.model_sample_map(canonical=df, sample_map='us_persona', female_bias=0.55, column_name='persona')
builder.add_column_description(column_name='persona', description="a base person template")

# %%
state_code = ['CA', 'NY', 'LA', 'NJ', 'VA', 'CO', 'NV', 'GA', 'IN', 'OH', 'KY', 'ME', 'MO', 'WI']
df = tools.model_sample_map(canonical=df, sample_map='us_zipcode', state_filter=state_code, column_name='zipcodes')
builder.add_column_description(column_name='zipcodes', description="Only covering 14 states woth a distribution based on population density")

# %%
# build up address starting with a number
df['address'] = tools.get_number(from_value=1, to_value=300000, precision=0, relative_freq=[50,10,5,3,2,1,1,1,1,], size=sample_size, column_name='address', intent_order=0)
builder.add_column_description(column_name='address', description="A realistc non-complex address")

# %%
# add in a name
df['address'] = tools.correlate_join(df, header='address', sep=' ', action=tools.action2dict(method='get_sample', sample_name='us_street_names', shuffle=True), column_name='address', intent_order=1)

# %%
# add road, sep=' ' types
df['address'] = tools.correlate_join(df, header='address', sep=' ', action=tools.action2dict(method='get_sample', sample_name='us_street_types', shuffle=True), column_name='address', intent_order=2)

# %%
# has phone number
df['has_phone_number'] = tools.get_category(selection=[1, 0], relative_freq=[15,1], size=sample_size, column_name='has_phone_number')
builder.add_column_description(column_name='has_phone_number', description="If the person has a phone number on record.")

# %%
# ensure only thoise with Phone numbers elect to not be called
selection = [builder.tools.select2dict(column='has_phone_number', condition='@==1')]

action = builder.tools.action2dict(method='get_category', selection=[1, 0], relative_freq=[1,20])
default = builder.tools.action2dict(method='@constant', value=0)

df['do_not_call'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='do_not_call')
builder.add_column_description(column_name='do_not_call', description="If the member has elected not to be called. Must have a phone number")

# %%
# communication channel preference
channels = ["SydneyCare", "RCP", "Phone", "Email", "SMS", "AgentAssist"]
df['channel_pref'] = tools.get_category(selection=channels, relative_freq=[4,1,3,2,2, 0.1], size=sample_size, column_name='channel_pref', intent_order=-1)
builder.add_column_description(column_name='channel_pref', description="The channel through which the member can be contacted")

# %%
# ensure if the preference is do not call the channel preference is not Phone
selection = [builder.tools.select2dict(column='do_not_call', condition='@==1'),
             builder.tools.select2dict(column='channel_pref', condition="@=='Phone'", logic='AND')]

action = builder.tools.action2dict(method='get_category', selection=["SydneyCare", "RCP", "Email", "SMS", "AgentAssist"], relative_freq=[2,1,2,2,0.1])
default = builder.tools.action2dict(method='@header', header='channel_pref')

df['channel_pref'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='channel_pref', intent_order=-1)
builder.add_column_description(column_name='channel_pref', description="ensure that if do_not_call is true the preference isn't by phone")

# %%
# ensure if the member has no phone number the channel preference is not SMS or Phone
selection = [builder.tools.select2dict(column='has_phone_number', condition='@==0')]

action = builder.tools.action2dict(method='get_category', selection=["SydneyCare", "RCP", "Email", "AgentAssist"], relative_freq=[2,1,2, 0.1])
default = builder.tools.action2dict(method='@header', header='channel_pref')

df['channel_pref'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='channel_pref', intent_order=-1)
builder.add_column_description(column_name='channel_pref', description="ensure if the member has no phone number the channel preference is not SMS or Phone")

# %%
# healthcare segment 
segment = ["Local Group", "National Accounts", "Medicaid", "BlueCard", "Medicare", "FEP", "Individual"]
df['segment'] = tools.get_category(selection=segment, relative_freq=[38, 19, 18, 15, 5, 4, 2], size=sample_size, column_name='segment')
builder.add_column_description(column_name='segment', description="The heathcare segment of the member with bias weighting")

# %%
# # line of buisness
correlations = [["Medicaid", "Medicare"]]
actions = {0: tools.action2dict(method='@constant', value='Business')}

df['line_of_business'] = tools.correlate_categories(df, header='segment', correlations=correlations, actions=actions, default_action='Commercial', column_name='line_of_business')
builder.add_column_description(column_name='line_of_business', description="The line of business this segment is in")

# %%
# data of birth
df['dob'] = tools.get_datetime(start=-36000, until=-6600, relative_freq=[0.01, 0.1, 1, 2, 3, 4, 2, 3], date_format='%Y-%m-%d', size=sample_size, column_name='dob')
builder.add_column_description(column_name='dob', description="dob has a distribution that peaks around the mid 40's with a negative skew and older outliers")

# %%
df['age'] = tools.correlate_dates(df, header='dob', now_delta='Y', year_first=True, column_name='age')
builder.add_column_description(column_name='age', description="converts the dob into an age as of today for reference in other attributes selections")

# %%
sns.set()
sns.distplot(df['age'], bins=20)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
# Adjust age for medicare being over 65
selection = [tools.select2dict(column='segment', condition="@=='Medicare'")]

action = tools.action2dict(method='get_number', from_value=65, to_value=90, relative_freq=[4,1,0.1])
default = tools.action2dict(method='@header', header='age')

df['age'] = tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='age', intent_order=-1)
builder.add_column_description(column_name='segment', description="Age is a conditional influencer with Medicare being exclusivly over 65")

# %%
# remove some emails addresses for over 60's
selection = [builder.tools.select2dict(column='age', condition='@ >= 60')]

action = builder.tools.action2dict(method='get_category', selection=[1, 0], relative_freq=[50, 1])

df['has_email'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=1, column_name='has_email')
builder.add_column_description(column_name='has_email', description="If the member has an email address on record")

# %%
# match the email to the has_email
selection = [builder.tools.select2dict(column='has_email', condition='@ == 0')]

action = tools.action2dict(method='@constant', value="")
default = tools.action2dict(method='@header', header='email')

df['email'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='email')
builder.add_column_description(column_name='email', description="trimming those with email address for over 60s from the persona emails")

# %%
# prev_flu_shot
df['prev_flu_shot'] = tools.get_category(selection=[1, 0], relative_freq=[4.5, 5.5], size=sample_size, column_name='prev_flu_shot', intent_order=-1)
builder.add_column_description(column_name='prev_flu_shot', description="If the member has had a flu shot in the previous season. Distribution based upon the figures taken from The Advisory Committee on Immunization Practices (ACIP)")

# %%
# adjust previous flu shot for under 49
selection = [builder.tools.select2dict(column='age', condition='@<49')]

action = builder.tools.action2dict(method='get_category', selection=[1, 0], relative_freq=[3,7])
default = builder.tools.action2dict(method='@header', header='prev_flu_shot')

df['prev_flu_shot'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='prev_flu_shot', intent_order=-1)

# %%
# adjust flu shot for over 75
selection = [builder.tools.select2dict(column='age', condition='@>65')]

action = builder.tools.action2dict(method='get_category', selection=[1, 0], relative_freq=[6.5, 3.5])
default = builder.tools.action2dict(method='@header', header='prev_flu_shot')

df['prev_flu_shot'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='prev_flu_shot', intent_order=-1)

# %%
# add a date in if previous flushot
selection = [builder.tools.select2dict(column='prev_flu_shot', condition='@==1')]

action = builder.tools.action2dict(method='get_datetime', start=-600, until=-300, relative_freq=[20, 10, 5, 1], ignore_time=True, date_format='%Y-%m-%d')
default = builder.tools.action2dict(method='@constant', value='')

df['last_flu_shot_date'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='last_flu_shot_date')
builder.add_column_description(column_name='segment', description="if had a previous flu shot, a date between 300 and 600 days previous to today")

# %%
# member health plan
df['member_health_plan'] = tools.get_category(selection=['PPO', 'HMO'], relative_freq=[6, 4], size=sample_size, column_name='member_health_plan')
builder.add_column_description(column_name='member_health_plan', description="The member health plan")

# %% [markdown]
# ### Asign a PCP to each member

# %%
# assign PCP tax_id
sample_data = tools.action2dict(method='model_sample_map', canonical=tools.action2dict(method='@empty'), sample_map='us_healthcare_practitioner', headers=['city', 'pcp_tax_id'], shuffle=False)
merge_data = tools.action2dict(method='model_group', canonical=sample_data, headers='pcp_tax_id', group_by='city', aggregator='list')
df = tools.model_merge(df, merge_data, how='left', left_on='city', right_on='city', column_name='pcp_tax_id')
builder.add_column_description(column_name='pcp_tax_id', description="Taken from the sample healthcare practitioners, matches a city to a practitioner list")

# %%
# select one of the options from the pcp_tax_id list
df['pcp_tax_id'] = tools.correlate_choice(df, header='pcp_tax_id', list_size=1, random_choice=True, shuffle=False, column_name='pcp_tax_id')

# %%
# is PCP auto assigned where there is a pc_tax_id
selection = [builder.tools.select2dict(column='pcp_tax_id', condition='@.isna()')]

df['is_PCP_auto_assigned'] = tools.correlate_selection(df, selection=selection, action=0, default_action=1, column_name='is_PCP_auto_assigned')
builder.add_column_description(column_name='is_PCP_auto_assigned', description="if the PCP has been auto assigned with a 7/3 positive distribution")

# %% [markdown]
# ### Run Reports

# %%
builder.canonical_report(df)
# Out:
# <style  type="text/css" >
#     #T_95d5a6fa_544d_11eb_ac09_784f439cb1c6 th {
#           font-size: 120%;
5a6fa_544d_11eb_ac09_784f439cb1c6row21_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row22_col2,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row22_col3,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row23_col2,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row23_col3,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row24_col2,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row24_col3,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row24_col6{
#             color:  black;
#         }#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row0_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row7_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row8_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row9_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row10_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row12_col3,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row12_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row15_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row18_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row19_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row24_col4{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row1_col1,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row5_col1,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row6_col1,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row12_col1,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row13_col1,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row14_col1,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row20_col1{
#             color:  #0f398a;
#         }#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row1_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row6_col3,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row6_col4{
#             background-color:  #fc9576;
#             color:  black;
#         }#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row1_col6{
#             background-color:  #f0f9ed;
#             color:  black;
#         }#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row2_col6,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row21_col6{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row3_col4{
#             background-color:  #f7593f;
#             color:  white;
#         }#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row4_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row5_col4{
#             background-color:  #fb7858;
#             color:  black;
#         }#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row6_col6,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row11_col6,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row12_col6,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row13_col6,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row14_col6,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row16_col6,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row17_col6,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row20_col6{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row13_col3,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row13_col4{
#             background-color:  #fcb499;
#             color:  black;
#         }#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row14_col3,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row16_col3,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row22_col4,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row23_col4{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row19_col1{
#             color:  #2f0f8a;
#         }#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row22_col6,#T_95d5a6fa_544d_11eb_ac09_784f439cb1c6row23_col6{
#             background-color:  #c1e6ba;
#             color:  black;
#         }</style><table id="T_95d5a6fa_544d_11eb_ac09_784f439cb1c6" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0"

# %%
builder.report_column_catalog()
# Out:
# <style  type="text/css" >
#     #T_95de7bc2_544d_11eb_ac09_784f439cb1c6 th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_95de7bc2_544d_11eb_ac09_784f439cb1c6 .row_heading, .blank {
#           display: none;;
#     }#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row0_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row1_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row2_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row3_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row4_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row5_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row6_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row7_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row8_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row9_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row10_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row11_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row12_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row13_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row14_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row15_col0,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row16_col0{
#             text-align:  left;
#             font-weight:  bold;
#         }#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row0_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row1_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row2_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row3_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row4_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row5_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row6_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row7_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row8_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row9_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row10_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row11_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row12_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row13_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row14_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row15_col1,#T_95de7bc2_544d_11eb_ac09_784f439cb1c6row16_col1{
#             text-align:  left;
#         }</style><table id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >column_name</th>        <th class="col_heading level0 col1" >description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row0_col0" class="data row0 col0" >address</td>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row0_col1" class="data row0 col1" >A realistc non-complex address</td>
#             </tr>
#             <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row1_col0" class="data row1 col0" >age</td>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row1_col1" class="data row1 col1" >converts the dob into an age as of today for reference in other attributes selections</td>
#             </tr>
#             <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row2_col0" class="data row2 col0" >channel_pref</td>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row2_col1" class="data row2 col1" >The channel through which the member can be contacted, ensure that if do_not_call is true the preference isn't by phone, ensure if the member has no phone number the channel preference is not SMS or Phone</td>
#             </tr>
#             <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row3_col0" class="data row3 col0" >do_not_call</td>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row3_col1" class="data row3 col1" >If the member has elected not to be called. Must have a phone number</td>
#             </tr>
#             <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row4_col0" class="data row4 col0" >dob</td>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row4_col1" class="data row4 col1" >dob has a distribution that peaks around the mid 40's with a negative skew and older outliers</td>
#             </tr>
#             <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row5_col0" class="data row5 col0" >email</td>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row5_col1" class="data row5 col1" >trimming those with email address for over 60s from the persona emails</td>
#             </tr>
#             <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row6_col0" class="data row6 col0" >has_email</td>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row6_col1" class="data row6 col1" >If the member has an email address on record</td>
#             </tr>
#             <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row7_col0" class="data row7 col0" >has_phone_number</td>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row7_col1" class="data row7 col1" >If the person has a phone number on record.</td>
#             </tr>
#             <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row8_col0" class="data row8 col0" >is_PCP_auto_assigned</td>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row8_col1" class="data row8 col1" >if the PCP has been auto assigned with a 7/3 positive distribution</td>
#             </tr>
#             <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row9_col0" class="data row9 col0" >last_flu_shot_date</td>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row9_col1" class="data row9 col1" ></td>
#             </tr>
#             <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row10_col0" class="data row10 col0" >line_of_business</td>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row10_col1" class="data row10 col1" >The line of business this segment is in</td>
#             </tr>
#             <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row11_col0" class="data row11 col0" >member_health_plan</td>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row11_col1" class="data row11 col1" >The member health plan</td>
#             </tr>
#             <tr>
#                         <th id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_95de7bc2_544d_11eb_ac09_784f439cb1c6row12_col0" class

# %%
builder.report_intent()
# Out:
# <style  type="text/css" >
#     #T_95e6d6b4_544d_11eb_ac09_784f439cb1c6 th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_95e6d6b4_544d_11eb_ac09_784f439cb1c6 .row_heading, .blank {
#           display: none;;
,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row14_col4,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row15_col1,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row15_col2,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row15_col3,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row15_col4,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row16_col1,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row16_col2,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row16_col3,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row16_col4,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row17_col1,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row17_col2,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row17_col3,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row17_col4,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row18_col1,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row18_col2,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row18_col3,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row18_col4,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row19_col1,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row19_col2,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row19_col3,#T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row19_col4,#T_95e6d6b4_544d_11eb_ac09_784f ...
#             text-align:  left;
#         }</style><table id="T_95e6d6b4_544d_11eb_ac09_784f439cb1c6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >level</th>        <th class="col_heading level0 col1" >order</th>        <th class="col_heading level0 col2" >intent</th>        <th class="col_heading level0 col3" >parameters</th>        <th class="col_heading level0 col4" >creator</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_95e6d6b4_544d_11eb_ac09_784f439cb1c6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row0_col0" class="data row0 col0" >address</td>
#                         <td id="T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row0_col2" class="data row0 col2" >get_number</td>
#                         <td id="T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row0_col3" class="data row0 col3" >['from_value=1', 'to_value=300000', 'relative_freq=[50, 10, 5, 3, 2, 1, 1, 1, 1]', 'precision=0', "column_name='address'"]</td>
#                         <td id="T_95e6d6b4_544d_11eb_ac09_784f439cb1c6row0_col4" class="data row0 col4" >doatridge</td>
#             </tr>
#             <tr>
#                         <th id="T_95e6d6b4_544d_11eb_ac09_784f439cb1c6level0_row1" class="row_heading level0 row1" >

# %% [markdown]
# ## Run the Pipeline  save the Schema and show the Canonical Report

# %%
# run the pipeline
builder.run_synthetic_pipeline(size=sample_size)

# save the schama from the pipeline outcome
builder.save_canonical_schema()

# report the stored schema
builder.report_canonical_schema(stylise=True)
# Out:
#             color:  #0f398a;
#         }#T_982e9132_544d_11eb_ac09_784f439cb1c6row1_col5{
#             background-color:  #f0f9ed;
#             color:  black;
#         }#T_982e9132_544d_11eb_ac09_784f439cb1c6row2_col5,#T_982e9132_544d_11eb_ac09_784f439cb1c6row21_col5{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_982e9132_544d_11eb_ac09_784f439cb1c6row6_col3{
#             background-color:  #fc9576;
#             color:  black;
#         }#T_982e9132_544d_11eb_ac09_784f439cb1c6row6_col5,#T_982e9132_544d_11eb_ac09_784f439cb1c6row11_col5,#T_982e9132_544d_11eb_ac09_784f439cb1c6row12_col5,#T_982e9132_544d_11eb_ac09_784f439cb1c6row13_col5,#T_982e9132_544d_11eb_ac09_784f439cb1c6row14_col5,#T_982e9132_544d_11eb_ac09_784f439cb1c6row16_col5,#T_982e9132_544d_11eb_ac09_784f439cb1c6row17_col5,#T_982e9132_544d_11eb_ac09_784f439cb1c6row20_col5{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_982e9132_544d_11eb_ac09_784f439cb1c6row12_col3{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_982e9132_544d_11eb_ac09_784f439cb1c6row13_col3{
#             background-color:  #fcb499;
#             color:  black;
#         }#T_982e9132_544d_11eb_ac09_784f439cb1c6row14_col3,#T_982e9132_544d_11eb_ac09_784f439cb1c6row16_col3{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_982e9132_544d_11eb_ac09_784f439cb1c6row19_col1{
#             color:  #2f0f8a;
#         }#T_982e9132_544d_11eb_ac09_784f439cb1c6row22_col5,#T_982e9132_544d_11eb_ac09_784f439cb1c6row23_col5{
#             background-color:  #c1e6ba;
#             color:  black;
#         }</style><table id="T_982e9132_544d_11eb_ac09_784f439cb1c6" ><caption>%_Dom: The % most dominant element - %_Nxt: The % next most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (25)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col4" >Count</th>        <th class="col_heading level0 col5" >Unique</th>        <th class="col_heading level0 col6" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_982e9132_544d_11eb_ac09_784f439cb1c6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_982e9132_544d_11eb_ac09_784f439cb1c6row0_col0" class="data row0 col0" >address</td>
#                         <td id="T_982e9132_544d_11eb_ac09_784f439cb1c6row0_col1" class="data row0 col1" >object</td>
#                         <td id="T_982e9132_544d_11eb_ac09_784f439cb1c6row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_982e9132_544d_11eb_ac09_784f439cb1c6row0_col3" class="data row0 col3" >0.1%</td>
#                         <td id="T_982e9132_544d_11eb_ac09_784f439cb1c6row0_col4" class="data row0 col4" >1000</td>
#                         <td id="T_982e9132_544d_11eb_ac09_784f439cb1c6row0_col5" class="data row0 col5" >1000</td>
#                         <td id="T_982e9132_544d_11eb_ac09_784f439cb1c6row0_col6" class="data row0 col6" >Sample: 61235 Culham Ci

# %% [markdown]
# -------------------------
# ## Members Transition

# %%
tr = Transition.from_env(task_name)

# %%
tr.pm.reset_intents()
tr.pm_persist()

# %%
df = tr.load_source_canonical()

# %%
# clean the data
tr.cleaners.auto_clean_header(df, inplace=True)
tr.cleaners.auto_transition(df, inplace=True)
tr.cleaners.to_str_type(df, dtype='object', inplace=True)
tr.cleaners.to_str_type(df, headers=['address', 'city', 'county', 'state', 'first_name', 'family_name', 'middle_name', 'email'], use_string_type=True, inplace=True)
tr.cleaners.to_date_type(df, headers='last_flu_shot_date', inplace=True)
tr.cleaners.to_remove(df, headers=['prev_flu_shot', 'age', 'county_fips'], inplace=True)

# %% [markdown]
# ## Run the Pipeline  save the Schema and show the Schema Report

# %%
# run the pipeline
tr.run_transition_pipeline()

# save the schama from the pipeline outcome
tr.save_canonical_schema()

# report the stored schema
tr.report_canonical_schema(stylise=True)
# Out:
# <style  type="text/css" >
#     #T_989e1ebc_544d_11eb_ac09_784f439cb1c6 th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_989e1ebc_544d_11eb_ac09_784f439cb1c6 .row_heading, .blank {
#           display: none;;
#     }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row0_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row1_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row2_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row3_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row4_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row5_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row6_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row7_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row8_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row9_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row10_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row11_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row12_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row13_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row14_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row15_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row16_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row17_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row18_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row19_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row20_col0,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row21_col0{
#             font-weight:  bold;
#             font-size:  120%;
09_784f439cb1c6row16_col3,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row16_col5,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row17_col2,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row17_col3,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row17_col5,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row18_col2,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row18_col3,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row19_col2,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row19_col3,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row20_col2,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row20_col3,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row21_col2,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row21_col3,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row21_col5{
#             color:  black;
#         }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row1_col1,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row9_col1,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row14_col1,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row15_col1,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row18_col1,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row20_col1{
#             color:  #208a0f;
#         }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row1_col5,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row18_col5{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row4_col1,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row10_col1,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row11_col1,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row12_col1{
#             color:  #08488e;
#         }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row4_col3{
#             background-color:  #fc9576;
#             color:  black;
#         }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row4_col5,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row9_col5,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row10_col5,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row11_col5,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row12_col5,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row14_col5,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row15_col5{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row5_col1,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row13_col1{
#             color:  #790f8a;
#         }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row10_col3{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row11_col3{
#             background-color:  #fcb499;
#             color:  black;
#         }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row12_col3,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row14_col3{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row17_col1{
#             color:  #2f0f8a;
#         }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row19_col5,#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row20_col5{
#             background-color:  #c1e6ba;
#             color:  black;
#         }#T_989e1ebc_544d_11eb_ac09_784f439cb1c6row21_col1{
#             color:  #0f398a;
#         }</style><table id="T_989e1ebc_544d_11eb_ac09_784f439cb1c6" ><caption>%_Dom: The % most dominant element - %_Nxt: The % next most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (22)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col4" >Count</th>        <th class="col_heading level0 col5" >Unique</th>        <th class="col_heading level0 col6" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_989e1ebc_544d_11eb_ac09_784f439cb1c6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_989e1ebc_544d_11eb_ac09_784f439cb1c6row0_col0" class="data row0 col0" >address</td>
#                         <td id="T_989e1ebc_544d_11eb_ac09_784f439cb1c6row0_col1" class="data row0 col1" >string</td>
#                         <td id="T_989e1ebc_544d_11eb_ac09_784f439cb1c6row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_989e1ebc_544d_11eb_ac09_784f439cb1c6row0_col3" class="data row0 col3" >0.1%</td>
#                         <td id="T_989e1ebc_544d_11eb_ac09_784f439cb1c6row0_col4" class="data row0 col4" >1000</td>
#                         <td id="T_989e1ebc_544d_11eb_ac09_784f439cb1c6r

# %% [markdown]
# -------------------------
# ## Hello World Members Transition

# %%
tr_hw = Transition.from_env('hello_world_members')

# %%
tr_hw.pm.reset_intents()
tr_hw.pm_persist()

# %%
df = tr_hw.load_source_canonical()

# %%
# clean the data
tr_hw.cleaners.auto_clean_header(df, inplace=True)
tr_hw.cleaners.auto_transition(df, inplace=True)
tr_hw.cleaners.to_str_type(df, dtype='object', inplace=True)
tr_hw.cleaners.to_str_type(df, headers=['address', 'city', 'county', 'state', 'first_name', 'family_name', 'middle_name', 'email'], use_string_type=True, inplace=True)
tr_hw.cleaners.to_date_type(df, headers='last_flu_shot_date', inplace=True)
tr_hw.cleaners.to_remove(df, headers=['dob', 'email', 'prev_flu_shot', 'county_fips'], inplace=True)

# %% [markdown]
# ## Run the Pipeline  save the Schema and show the Schema Report

# %%
# run the pipeline
tr_hw.run_transition_pipeline()

# save the schama from the pipeline outcome
tr_hw.save_canonical_schema()

# report the stored schema
tr_hw.report_canonical_schema(stylise=True)
# Out:
# <style  type="text/css" >
#     #T_990da3e0_544d_11eb_ac09_784f439cb1c6 th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_990da3e0_544d_11eb_ac09_784f439cb1c6 .row_heading, .blank {
#           display: none;;
#         }#T_990da3e0_544d_11eb_ac09_784f439cb1c6row5_col1,#T_990da3e0_544d_11eb_ac09_784f439cb1c6row9_col1,#T_990da3e0_544d_11eb_ac09_784f439cb1c6row10_col1,#T_990da3e0_544d_11eb_ac09_784f439cb1c6row11_col1{
#             color:  #08488e;
#         }#T_990da3e0_544d_11eb_ac09_784f439cb1c6row5_col3{
#             background-color:  #fc9576;
#             color:  black;
#         }#T_990da3e0_544d_11eb_ac09_784f439cb1c6row5_col5,#T_990da3e0_544d_11eb_ac09_784f439cb1c6row8_col5,#T_990da3e0_544d_11eb_ac09_784f439cb1c6row9_col5,#T_990da3e0_544d_11eb_ac09_784f439cb1c6row10_col5,#T_990da3e0_544d_11eb_ac09_784f439cb1c6row11_col5,#T_990da3e0_544d_11eb_ac09_784f439cb1c6row13_col5,#T_990da3e0_544d_11eb_ac09_784f439cb1c6row14_col5{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_990da3e0_544d_11eb_ac09_784f439cb1c6row9_col3{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_990da3e0_544d_11eb_ac09_784f439cb1c6row10_col3{
#             background-color:  #fcb499;
#             color:  black;
#         }#T_990da3e0_544d_11eb_ac09_784f439cb1c6row11_col3,#T_990da3e0_544d_11eb_ac09_784f439cb1c6row13_col3{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_990da3e0_544d_11eb_ac09_784f439cb1c6row12_col1{
#             color:  #790f8a;
#         }#T_990da3e0_544d_11eb_ac09_784f439cb1c6row16_col1{
#             color:  #2f0f8a;
#         }#T_990da3e0_544d_11eb_ac09_784f439cb1c6row18_col5,#T_990da3e0_544d_11eb_ac09_784f439cb1c6row19_col5{
#             background-color:  #c1e6ba;
#             color:  black;
#         }</style><table id="T_990da3e0_544d_11eb_ac09_784f439cb1c6" ><caption>%_Dom: The % most dominant element - %_Nxt: The % next most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (21)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col4" >Count</th>        <th class="col_heading level0 col5" >Unique</th>        <th class="col_heading level0 col6" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_990da3e0_544d_11eb_ac09_784f439cb1c6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_990da3e0_544d_11eb_ac09_784f439cb1c6row0_col0" class="data row0 col0" >address</td>
#                         <td id="T_990da3e0_544d_11eb_ac09_784f439cb1c6row0_col1" class="data row0 col1" >string</td>
#                         <td id="T_990da3e0_544d_11eb_ac09_784f439cb1c6row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_990da3e0_544d_11eb_ac09_784f439cb1c6row0_col3" class="data row0 col3" >0.1%</td>
#                         <td id="T_990da3e0_544d_11eb_ac09_784f439cb1c6row0_col4" class="data row0 col4" >1000</td>
#                         <td id="T_990da3e0_544d_11eb_ac09_784f439cb1c6row0_col5" class="data row0 col5" >1000</td>
#                         <td id="T_990da3e0_544d_11eb_ac09_784f439cb1c6row0_col6" class="data row0 col6" >Sample: 61235 Culham Cir
