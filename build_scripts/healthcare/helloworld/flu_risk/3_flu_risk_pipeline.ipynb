# %%
# %run ../base_setup.ipynb
# Out:
# Foundation: 2.11.018
# Transition: 3.01.007
# Engines   : 2.03.028

# %%
sample_size = 10000
seed = None

# %% [markdown]
# -------------------------
# ## Flu Risk Builder

# %%
builder = SyntheticBuilder.from_env('flu_risk')

# %% [markdown]
# ### Run the Pipeline  save the Schema and show the Canonical Report

# %%
# set the version
builder.set_version(VERSION)

# run the pipeline
builder.run_synthetic_pipeline(size=sample_size)

# report
builder.canonical_report(builder.load_synthetic_canonical(), stylise=True)
# Out:
# <style  type="text/css" >
#     #T_ab1a0_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_ab1a0_ .row_heading, .blank {
#           display: none;;
#     }#T_ab1a0_row0_col0,#T_ab1a0_row1_col0,#T_ab1a0_row2_col0,#T_ab1a0_row3_col0,#T_ab1a0_row4_col0,#T_ab1a0_row5_col0,#T_ab1a0_row6_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_ab1a0_row0_col1,#T_ab1a0_row5_col1{
#             color:  #0f398a;
#         }#T_ab1a0_row0_col2,#T_ab1a0_row0_col3,#T_ab1a0_row1_col2,#T_ab1a0_row1_col3,#T_ab1a0_row1_col4,#T_ab1a0_row2_col2,#T_ab1a0_row3_col2,#T_ab1a0_row3_col3,#T_ab1a0_row3_col6,#T_ab1a0_row4_col2,#T_ab1a0_row4_col3,#T_ab1a0_row4_col4,#T_ab1a0_row5_col2,#T_ab1a0_row5_col3,#T_ab1a0_row5_col6,#T_ab1a0_row6_col2,#T_ab1a0_row6_col3{
#             color:  black;
#         }#T_ab1a0_row0_col4{
#             background-color:  #fc9576;
#             color:  black;
#         }#T_ab1a0_row0_col6{
#             background-color:  #f0f9ed;
#             color:  black;
#         }#T_ab1a0_row1_col1,#T_ab1a0_row3_col1{
#             color:  #2f0f8a;
#         }#T_ab1a0_row1_col6{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_ab1a0_row2_col3,#T_ab1a0_row2_col4,#T_ab1a0_row2_col6,#T_ab1a0_row3_col4,#T_ab1a0_row5_col4{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_ab1a0_row4_col1{
#             color:  #208a0f;
#         }#T_ab1a0_row4_col6{
#             background-color:  #84cc83;
#             color:  black;
#         }#T_ab1a0_row6_col1{
#             color:  #761d38;
#         }#T_ab1a0_row6_col4{
#             background-color:  #fdcdb9;
#             color:  black;
#         }#T_ab1a0_row6_col6{
#             background-color:  #c1e6ba;
#             color:  black;
#         }</style><table id="T_ab1a0_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (7)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ab1a0_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ab1a0_row0_col0" class="data row0 col0" >age</td>
#                         <td id="T_ab1a0_row0_col1" class="data row0 col1" >int64</td>
#                         <td id="T_ab1a0_row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_ab1a0_row0_col3" class="data row0 col3" >3.5%</td>
#                                 <td id="T_ab1a0_row0_col5" class="data row0 col5" >10000</td>
#                         <td id="T_ab1a0_row0_col6" class="data row0 col6" >71</td>
#                         <td id="T_ab1a0_row0_col7" class="data row0 col7" >max=91 | min=21 | mean=39.62 | dominant=27</td>
#             </tr>
#             <tr>
#                         <th id="T_ab1a0_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ab1a0_row1_col0" class="data row1 col0" >age_privilege</td>
#                         <td id="T_ab1a0_row1_col1" class="data row1 col1" >float64</td>
#                         <td id="T_ab1a0_row1_col2" class="data row1 col2" >0.0%</td>
#                         <td id="T_ab1a0_row1_col3" class="data row1 col3" >60.3%</td>
#                                 <td id="T_ab1a0_row1_col5" class="data row1 col5" >10000</td>
#                         <td id="T_ab1a0_row1_col6" class="data row1 col6" >7</td>
#                         <td id="T_ab1a0_row1_col7" class="data row1 col7" >max=0.2 | min=-0.1 | mean=-0.04 | dominant=-0.1</td>
#             </tr>
#             <tr>
#                         <th id="T_ab1a0_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ab1a0_row2_col0" class="data row2 col0" >date</td>
#                         <td id="T_ab1a0_row2_col1" class="data row2 col1" >object</td>
#                         <td id="T_ab1a0_row2_col2" class="data row2 col2" >0.0%</td>
#                         <td id="T_ab1a0_row2_col3" class="data row2 col3" >100.0%</td>
#                                 <td id="T_ab1a0_row2_col5" class="data row2 col5" >10000</td>
#                         <td id="T_ab1a0_row2_col6" class="data row2 col6" >1</td>
#                         <td id="T_ab1a0_row2_col7" class="data row2 col7" >Sample: 2021-01-28</td>
#             </tr>
#             <tr>
#                         <th id="T_ab1a0_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ab1a0_row3_col0" class="data row3 col0" >flu_risk_score</td>
#                         <td id="T_ab1a0_row3_col1" class="data row3 col1" >float64</td>
#                         <td id="T_ab1a0_row3_col2" class="data row3 col2" >0.0%</td>
#                         <td id="T_ab1a0_row3_col3" class="data row3 col3" >0.3%</td>
#                                 <td id="T_ab1a0_row3_col5" class="data row3 col5" >10000</td>
#                         <td id="T_ab1a0_row3_col6" class="data row3 col6" >969</td>
#                         <td id="T_ab1a0_row3_col7" class="data row3 col7" >max=0.999 | min=0.001 | mean=0.39 | dominant=[0.396, 0.434]</td>
#             </tr>
#             <tr>
#                         <th id="T_ab1a0_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ab1a0_row4_col0" class="data row4 col0" >ins_icd_10_code</td>
#                         <td id="T_ab1a0_row4_col1" class="data row4 col1" >category</td>
#                         <td id="T_ab1a0_row4_col2" class="data row4 col2" >0.0%</td>
#                         <td id="T_ab1a0_row4_col3" class="data row4 col3" >54.9%</td>
#                                 <td id="T_ab1a0_row4_col5" class="data row4 col5" >10000</td>
#                         <td id="T_ab1a0_row4_col6" class="data row4 col6" >3</td>
#                         <td id="T_ab1a0_row4_col7" class="data row4 col7" >Sample: 0 | Z23 | Z28</td>
#             </tr>
#             <tr>
#                         <th id="T_ab1a0_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ab1a0_row5_col0" class="data row5 col0" >member_id</td>
#                         <td id="T_ab1a0_row5_col1" class="data row5 col1" >int64</td>
#                         <td id="T_ab1a0_row5_col2" class="data row5 col2" >0.0%</td>
#                         <td id="T_ab1a0_row5_col3" class="data row5 col3" >0.0%</td>
#                                 <td id="T_ab1a0_row5_col5" class="data row5 col5" >10000</td>
#                         <td id="T_ab1a0_row5_col6" class="data row5 col6" >10000</td>
#                         <td id="T_ab1a0_row5_col7" class="data row5 col7" >max=999833289 | min=100080999 | mean=550883893.14 | dominant=[100080999, 100193499]</td>
#             </tr>
#             <tr>
#                         <th id="T_ab1a0_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ab1a0_row6_col0" class="data row6 col0" >state</td>
#                         <td id="T_ab1a0_row6_col1" class="data row6 col1" >string</td>
#                         <td id="T_ab1a0_row6_col2" class="data row6 col2" >0.0%</td>
#                         <td id="T_ab1a0_row6_col3" class="data row6 col3" >19.9%</td>
#                                 <td id="T_ab1a0_row6_col5" class="data row6 col5" >10000</td>
#                         <td id="T_ab1a0_row6_col6" class="data row6 col6" >14</td>
#                         <td id="T_ab1a0_row6_col7" class="data row6 col7" >Sample: California | New York | Ohio | Missouri | Georgia</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Save Reports

# %%
builder.save_report_canonical(report_connector_name=builder.REPORT_INTENT, report=builder.report_intent(stylise=False))
builder.save_report_canonical(report_connector_name=builder.REPORT_CATALOG, report=builder.report_column_catalog(stylise=False))

# %% [markdown]
# -------------------------
# ## Flu Risk Transition

# %%
tr = Transition.from_env('flu_risk')

# %%
# set the version
tr.set_version(VERSION)

# run the pipeline
tr.run_transition_pipeline()

# report
tr.canonical_report(tr.load_clean_canonical(), stylise=True)
# Out:
# <style  type="text/css" >
#     #T_d6ed9_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_d6ed9_ .row_heading, .blank {
#           display: none;;
#     }#T_d6ed9_row0_col0,#T_d6ed9_row1_col0,#T_d6ed9_row2_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_d6ed9_row0_col2,#T_d6ed9_row1_col2,#T_d6ed9_row1_col3,#T_d6ed9_row1_col6,#T_d6ed9_row2_col2,#T_d6ed9_row2_col3,#T_d6ed9_row2_col6{
#             color:  black;
#         }#T_d6ed9_row0_col3,#T_d6ed9_row0_col4,#T_d6ed9_row0_col6,#T_d6ed9_row1_col4,#T_d6ed9_row2_col4{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_d6ed9_row1_col1{
#             color:  #2f0f8a;
#         }#T_d6ed9_row2_col1{
#             color:  #0f398a;
#         }</style><table id="T_d6ed9_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (3)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d6ed9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d6ed9_row0_col0" class="data row0 col0" >date</td>
#                         <td id="T_d6ed9_row0_col1" class="data row0 col1" >object</td>
#                         <td id="T_d6ed9_row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_d6ed9_row0_col3" class="data row0 col3" >100.0%</td>
#                                 <td id="T_d6ed9_row0_col5" class="data row0 col5" >10000</td>
#                         <td id="T_d6ed9_row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_d6ed9_row0_col7" class="data row0 col7" >Sample: 2021-01-28</td>
#             </tr>
#             <tr>
#                         <th id="T_d6ed9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d6ed9_row1_col0" class="data row1 col0" >flu_risk_score</td>
#                         <td id="T_d6ed9_row1_col1" class="data row1 col1" >float64</td>
#                         <td id="T_d6ed9_row1_col2" class="data row1 col2" >0.0%</td>
#                         <td id="T_d6ed9_row1_col3" class="data row1 col3" >0.3%</td>
#                                 <td id="T_d6ed9_row1_col5" class="data row1 col5" >10000</td>
#                         <td id="T_d6ed9_row1_col6" class="data row1 col6" >969</td>
#                         <td id="T_d6ed9_row1_col7" class="data row1 col7" >max=0.999 | min=0.001 | mean=0.39 | dominant=[0.396, 0.434]</td>
#             </tr>
#             <tr>
#                         <th id="T_d6ed9_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d6ed9_row2_col0" class="data row2 col0" >member_id</td>
#                         <td id="T_d6ed9_row2_col1" class="data row2 col1" >int64</td>
#                         <td id="T_d6ed9_row2_col2" class="data row2 col2" >0.0%</td>
#                         <td id="T_d6ed9_row2_col3" class="data row2 col3" >0.0%</td>
#                                 <td id="T_d6ed9_row2_col5" class="data row2 col5" >10000</td>
#                         <td id="T_d6ed9_row2_col6" class="data row2 col6" >10000</td>
#                         <td id="T_d6ed9_row2_col7" class="data row2 col7" >max=999833289 | min=100080999 | mean=550883893.14 | dominant=[100080999, 100193499]</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Save Reports

# %%
tr.save_report_canonical(report_connector_name=tr.REPORT_DICTIONARY, report=tr.canonical_report(tr.load_clean_canonical(), stylise=False))
tr.save_report_canonical(report_connector_name=tr.REPORT_SUMMARY, report=tr.report_quality_summary(stylise=False))
tr.save_report_canonical(report_connector_name=tr.REPORT_PROVENANCE, report=tr.report_provenance(stylise=False))
tr.save_report_canonical(report_connector_name=tr.REPORT_FIELDS, report=tr.report_attributes(tr.load_clean_canonical(), stylise=False))

# %% [markdown]
# -------------------------
# ## Action Feedback Builder

# %%
builder = SyntheticBuilder.from_env('action_feedback')

# %% [markdown]
# ### Run the Pipeline  save the Schema and show the Canonical Report

# %%
# set the version
builder.set_version(VERSION)

# run the pipeline
builder.run_synthetic_pipeline(size=sample_size)

# report
builder.canonical_report(builder.load_synthetic_canonical(), stylise=True)
# Out:
# <style  type="text/css" >
#     #T_9408e_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_9408e_ .row_heading, .blank {
#           display: none;;
#     }#T_9408e_row0_col0,#T_9408e_row1_col0,#T_9408e_row2_col0,#T_9408e_row3_col0,#T_9408e_row4_col0,#T_9408e_row5_col0,#T_9408e_row6_col0,#T_9408e_row7_col0,#T_9408e_row8_col0,#T_9408e_row9_col0,#T_9408e_row10_col0,#T_9408e_row11_col0,#T_9408e_row12_col0,#T_9408e_row13_col0,#T_9408e_row14_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_9408e_row0_col2,#T_9408e_row0_col3,#T_9408e_row0_col4,#T_9408e_row1_col2,#T_9408e_row1_col3,#T_9408e_row1_col6,#T_9408e_row2_col2,#T_9408e_row2_col3,#T_9408e_row2_col6,#T_9408e_row3_col2,#T_9408e_row4_col2,#T_9408e_row4_col3,#T_9408e_row4_col6,#T_9408e_row5_col2,#T_9408e_row6_col2,#T_9408e_row6_col3,#T_9408e_row6_col6,#T_9408e_row7_col2,#T_9408e_row7_col3,#T_9408e_row7_col4,#T_9408e_row8_col2,#T_9408e_row8_col3,#T_9408e_row8_col4,#T_9408e_row9_col2,#T_9408e_row9_col3,#T_9408e_row9_col6,#T_9408e_row10_col2,#T_9408e_row11_col2,#T_9408e_row11_col3,#T_9408e_row11_col4,#T_9408e_row12_col2,#T_9408e_row12_col3,#T_9408e_row12_col4,#T_9408e_row13_col2,#T_9408e_row13_col3,#T_9408e_row13_col6,#T_9408e_row14_col2,#T_9408e_row14_col3,#T_9408e_row14_col4{
#             color:  black;
#         }#T_9408e_row0_col6,#T_9408e_row8_col6{
#             background-color:  #84cc83;
#             color:  black;
#         }#T_9408e_row1_col1{
#             color:  #790f8a;
#         }#T_9408e_row1_col4,#T_9408e_row2_col4,#T_9408e_row4_col4,#T_9408e_row6_col4,#T_9408e_row9_col4,#T_9408e_row13_col4{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_9408e_row3_col1,#T_9408e_row5_col1,#T_9408e_row6_col1,#T_9408e_row7_col1,#T_9408e_row11_col1,#T_9408e_row12_col1{
#             color:  #0f398a;
#         }#T_9408e_row3_col3,#T_9408e_row5_col3,#T_9408e_row5_col4{
#             background-color:  #fc9576;
#             color:  black;
#         }#T_9408e_row3_col4{
#             background-color:  #fb7858;
#             color:  black;
#         }#T_9408e_row3_col6,#T_9408e_row5_col6,#T_9408e_row7_col6{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_9408e_row10_col3,#T_9408e_row10_col4{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_9408e_row10_col6,#T_9408e_row11_col6,#T_9408e_row14_col6{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_9408e_row12_col6{
#             background-color:  #e5f5e0;
#             color:  black;
#         }</style><table id="T_9408e_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (15)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9408e_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9408e_row0_col0" class="data row0 col0" >actionable_id</td>
#                         <td id="T_9408e_row0_col1" class="data row0 col1" >object</td>
#                         <td id="T_9408e_row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_9408e_row0_col3" class="data row0 col3" >61.9%</td>
#                                 <td id="T_9408e_row0_col5" class="data row0 col5" >10000</td>
#                         <td id="T_9408e_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_9408e_row0_col7" class="data row0 col7" >Sample: 47613313 | 61284651 | 92188326</td>
#             </tr>
#             <tr>
#                         <th id="T_9408e_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9408e_row1_col0" class="data row1 col0" >feedback_dt</td>
#                         <td id="T_9408e_row1_col1" class="data row1 col1" >datetime64[ns]</td>
#                         <td id="T_9408e_row1_col2" class="data row1 col2" >0.0%</td>
#                         <td id="T_9408e_row1_col3" class="data row1 col3" >0.0%</td>
#                                 <td id="T_9408e_row1_col5" class="data row1 col5" >10000</td>
#                         <td id="T_9408e_row1_col6" class="data row1 col6" >10000</td>
#                         <td id="T_9408e_row1_col7" class="data row1 col7" >max=2021-02-10 20:17:30.423975 | min=2021-01-24 22:18:51.231968 | yr mean= 2021</td>
#             </tr>
#             <tr>
#                         <th id="T_9408e_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9408e_row2_col0" class="data row2 col0" >feedback_id</td>
#                         <td id="T_9408e_row2_col1" class="data row2 col1" >object</td>
#                         <td id="T_9408e_row2_col2" class="data row2 col2" >0.0%</td>
#                         <td id="T_9408e_row2_col3" class="data row2 col3" >0.2%</td>
#                                 <td id="T_9408e_row2_col5" class="data row2 col5" >10000</td>
#                         <td id="T_9408e_row2_col6" class="data row2 col6" >1450</td>
#                         <td id="T_9408e_row2_col7" class="data row2 col7" >Sample: 202102121601 | 202102121725 | 202102112313 | 202102121825 | 202102121713</td>
#             </tr>
#             <tr>
#                         <th id="T_9408e_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9408e_row3_col0" class="data row3 col0" >has_interacted</td>
#                         <td id="T_9408e_row3_col1" class="data row3 col1" >int64</td>
#                         <td id="T_9408e_row3_col2" class="data row3 col2" >0.0%</td>
#                         <td id="T_9408e_row3_col3" class="data row3 col3" >97.5%</td>
#                                 <td id="T_9408e_row3_col5" class="data row3 col5" >10000</td>
#                         <td id="T_9408e_row3_col6" class="data row3 col6" >2</td>
#                         <td id="T_9408e_row3_col7" class="data row3 col7" >max=1 | min=0 | mean=0.97 | dominant=1</td>
#             </tr>
#             <tr>
#                         <th id="T_9408e_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9408e_row4_col0" class="data row4 col0" >has_interacted_dt</td>
#                         <td id="T_9408e_row4_col1" class="data row4 col1" >object</td>
#                         <td id="T_9408e_row4_col2" class="data row4 col2" >2.5%</td>
#                         <td id="T_9408e_row4_col3" class="data row4 col3" >2.5%</td>
#                                 <td id="T_9408e_row4_col5" class="data row4 col5" >10000</td>
#                         <td id="T_9408e_row4_col6" class="data row4 col6" >9715</td>
#                         <td id="T_9408e_row4_col7" class="data row4 col7" >Sample:  | 2021-01-22 18:28:34 | 2021-01-24 14:12:44 | 2021-01-27 02:21:51 | 2021-01-21 09:48:46</td>
#             </tr>
#             <tr>
#                         <th id="T_9408e_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9408e_row5_col0" class="data row5 col0" >has_permission</td>
#                         <td id="T_9408e_row5_col1" class="data row5 col1" >int64</td>
#                         <td id="T_9408e_row5_col2" class="data row5 col2" >0.0%</td>
#                         <td id="T_9408e_row5_col3" class="data row5 col3" >95.4%</td>
#                                 <td id="T_9408e_row5_col5" class="data row5 col5" >10000</td>
#                         <td id="T_9408e_row5_col6" class="data row5 col6" >2</td>
#                         <td id="T_9408e_row5_col7" class="data row5 col7" >max=1 | min=0 | mean=0.95 | dominant=1</td>
#             </tr>
#             <tr>
#                         <th id="T_9408e_leve

# %% [markdown]
# ### Save Reports

# %%
builder.save_report_canonical(report_connector_name=builder.REPORT_INTENT, report=builder.report_intent(stylise=False))
builder.save_report_canonical(report_connector_name=builder.REPORT_CATALOG, report=builder.report_column_catalog(stylise=False))

# %% [markdown]
# -------------------------
# ## Action Feedback Transition

# %%
tr = Transition.from_env('action_feedback')

# %%
# set the version
tr.set_version(VERSION)

# run the pipeline
tr.run_transition_pipeline()

# report
tr.canonical_report(tr.load_clean_canonical(), stylise=True)
# Out:
# <style  type="text/css" >
#     #T_b7545_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_b7545_ .row_heading, .blank {
#           display: none;;
#     }#T_b7545_row0_col0,#T_b7545_row1_col0,#T_b7545_row2_col0,#T_b7545_row3_col0,#T_b7545_row4_col0,#T_b7545_row5_col0,#T_b7545_row6_col0,#T_b7545_row7_col0,#T_b7545_row8_col0,#T_b7545_row9_col0,#T_b7545_row10_col0,#T_b7545_row11_col0,#T_b7545_row12_col0,#T_b7545_row13_col0,#T_b7545_row14_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_b7545_row0_col1,#T_b7545_row7_col1,#T_b7545_row9_col1,#T_b7545_row14_col1{
#             color:  #208a0f;
#         }#T_b7545_row0_col2,#T_b7545_row0_col3,#T_b7545_row0_col4,#T_b7545_row1_col2,#T_b7545_row1_col3,#T_b7545_row1_col6,#T_b7545_row2_col2,#T_b7545_row2_col3,#T_b7545_row2_col6,#T_b7545_row3_col2,#T_b7545_row4_col2,#T_b7545_row4_col3,#T_b7545_row4_col6,#T_b7545_row5_col2,#T_b7545_row6_col2,#T_b7545_row6_col3,#T_b7545_row6_col4,#T_b7545_row7_col2,#T_b7545_row7_col3,#T_b7545_row7_col4,#T_b7545_row8_col2,#T_b7545_row8_col3,#T_b7545_row8_col6,#T_b7545_row9_col2,#T_b7545_row10_col2,#T_b7545_row10_col3,#T_b7545_row10_col6,#T_b7545_row11_col2,#T_b7545_row11_col3,#T_b7545_row11_col4,#T_b7545_row12_col2,#T_b7545_row12_col3,#T_b7545_row12_col4,#T_b7545_row13_col2,#T_b7545_row13_col3,#T_b7545_row13_col6,#T_b7545_row14_col2,#T_b7545_row14_col3,#T_b7545_row14_col4{
#             color:  black;
#         }#T_b7545_row0_col6,#T_b7545_row7_col6{
#             background-color:  #84cc83;
#             color:  black;
#         }#T_b7545_row1_col1{
#             color:  #790f8a;
#         }#T_b7545_row1_col4,#T_b7545_row2_col4,#T_b7545_row4_col4,#T_b7545_row8_col4,#T_b7545_row10_col4,#T_b7545_row13_col4{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_b7545_row2_col1,#T_b7545_row10_col1,#T_b7545_row11_col1,#T_b7545_row12_col1{
#             color:  #0f398a;
#         }#T_b7545_row3_col1,#T_b7545_row5_col1,#T_b7545_row6_col1{
#             color:  #08488e;
#         }#T_b7545_row3_col3,#T_b7545_row5_col3,#T_b7545_row5_col4{
#             background-color:  #fc9576;
#             color:  black;
#         }#T_b7545_row3_col4{
#             background-color:  #fb7858;
#             color:  black;
#         }#T_b7545_row3_col6,#T_b7545_row5_col6,#T_b7545_row6_col6{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_b7545_row9_col3,#T_b7545_row9_col4{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_b7545_row9_col6,#T_b7545_row11_col6,#T_b7545_row14_col6{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_b7545_row12_col6{
#             background-color:  #e5f5e0;
#             color:  black;
#         }</style><table id="T_b7545_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (15)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b7545_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b7545_row0_col0" class="data row0 col0" >actionable_id</td>
#                         <td id="T_b7545_row0_col1" class="data row0 col1" >category</td>
#                         <td id="T_b7545_row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_b7545_row0_col3" class="data row0 col3" >61.9%</td>
#                                 <td id="T_b7545_row0_col5" class="data row0 col5" >10000</td>
#                         <td id="T_b7545_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_b7545_row0_col7" class="data row0 col7" >Sample: 47613313 | 61284651 | 92188326</td>
#             </tr>
#             <tr>
#                         <th id="T_b7545_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b7545_row1_col0" class="data row1 col0" >feedback_dt</td>
#                         <td id="T_b7545_row1_col1" class="data row1 col1" >datetime64[ns]</td>
#                         <td id="T_b7545_row1_col2" class="data row1 col2" >0.0%</td>
#                         <td id="T_b7545_row1_col3" class="data row1 col3" >0.0%</td>
#                                 <td id="T_b7545_row1_col5" class="data row1 col5" >10000</td>
#                         <td id="T_b7545_row1_col6" class="data row1 col6" >10000</td>
#                         <td id="T_b7545_row1_col7" class="data row1 col7" >max=2021-02-10 20:17:30.423975 | min=2021-01-24 22:18:51.231968 | yr mean= 2021</td>
#             </tr>
#             <tr>
#                         <th id="T_b7545_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b7545_row2_col0" class="data row2 col0" >feedback_id</td>
#                         <td id="T_b7545_row2_col1" class="data row2 col1" >int64</td>
#                         <td id="T_b7545_row2_col2" class="data row2 col2" >0.0%</td>
#                         <td id="T_b7545_row2_col3" class="data row2 col3" >0.2%</td>
#                                 <td id="T_b7545_row2_col5" class="data row2 col5" >10000</td>
#                         <td id="T_b7545_row2_col6" class="data row2 col6" >1450</td>
#                         <td id="T_b7545_row2_col7" class="data row2 col7" >max=202102122159 | min=202102112106 | mean=202102120304.99 | dominant=[202102121601, 202102121725]</td>
#             </tr>
#             <tr>
#                         <th id="T_b7545_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b7545_row3_col0" class="data row3 col0" >has_interacted</td>
#                         <td id="T_b7545_row3_col1" class="data row3 col1" >bool</td>
#                         <td id="T_b7545_row3_col2" class="data row3 col2" >0.0%</td>
#                         <td id="T_b7545_row3_col3" class="data row3 col3" >97.5%</td>
#                                 <td id="T_b7545_row3_col5" class="data row3 col5" >10000</td>
#                         <td id="T_b7545_row3_col6" class="data row3 col6" >2</td>
#                         <td id="T_b7545_row3_col7" class="data row3 col7" >True | False</td>
#             </tr>
#             <tr>
#                         <th id="T_b7545_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b7545_row4_col0" class="data row4 col0" >has_interacted_dt</td>
#                         <td id="T_b7545_row4_col1" class="data row4 col1" >object</td>
#                         <td id="T_b7545_row4_col2" class="data row4 col2" >2.5%</td>
#                         <td id="T_b7545_row4_col3" class="data row4 col3" >2.5%</td>
#                                 <td id="T_b7545_row4_col5" class="data row4 col5" >10000</td>
#                         <td id="T_b7545_row4_col6" class="data row4 col6" >9715</td>
#                         <td id="T_b7545_row4_col7" class="data row4 col7" >Sample:  | 2021-01-22 18:28:34 | 2021-01-24 14:12:44 | 2021-01-27 02:21:51 | 2021-01-21 09:48:46</td>
#             </tr>
#             <tr>
#                         <th id="T_b7545_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b7545_row5_col0" class="data row5 col0" >has_permission</td>
#                         <td id="T_b7545_row5_col1" class="data row5 col1" >bool</td>
#                         <td id="T_b7545_row5_col2" class="data row5 col2" >0.0%</td>
#                         <td id="T_b7545_row5_col3" class="data row5 col3" >95.4%</td>
#                                 <td id="T_b7545_row5_col5" class="data row5 col5" >10000</td>
#                         <td id="T_b7545_row5_col6" class="data row5 col6" >2</td>
#                         <td id="

# %% [markdown]
# ### Save Reports

# %%
tr.save_report_canonical(report_connector_name=tr.REPORT_DICTIONARY, report=tr.canonical_report(tr.load_clean_canonical(), stylise=False))
tr.save_report_canonical(report_connector_name=tr.REPORT_SUMMARY, report=tr.report_quality_summary(stylise=False))
tr.save_report_canonical(report_connector_name=tr.REPORT_PROVENANCE, report=tr.report_provenance(stylise=False))
tr.save_report_canonical(report_connector_name=tr.REPORT_FIELDS, report=tr.report_attributes(tr.load_clean_canonical(), stylise=False))
