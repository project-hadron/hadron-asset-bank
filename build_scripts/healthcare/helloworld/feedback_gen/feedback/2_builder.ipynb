# %%
# %run task_setup.ipynb
# Out:
# Foundation: 2.11.030
# Transition: 3.02.034

# %% [markdown]
# -------------------------
# ## Build Feedback synthetic file

# %%
builder = SyntheticBuilder.from_env('feedback')

# %%
tools = builder.intent_model

# %%
builder.pm.reset_intents()
builder.pm_persist()

# %% [markdown]
# ------------------------
# ### Load the watchlist

# %%
builder.add_connector_uri(connector_name='feedback', uri="s3://project-hadron-cs-repo/domain/helloworld/data/feedback/watchlist/plan_executor_results_09-03-2021.parquet", template_aligned=False)

# %%
df = tools.frame_starter(canonical='feedback', column_name='watchlist')
builder.add_column_description(column_name='watchlist', description="extracted watchlist from the plan executor")

# %%
sample_size = df.shape[0]

# %%
builder.canonical_report(df)
# Out:
# <style  type="text/css" >
#     #T_701e5_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_701e5_ .row_heading, .blank {
#           display: none;;
#     }#T_701e5_row0_col0,#T_701e5_row1_col0,#T_701e5_row2_col0,#T_701e5_row3_col0,#T_701e5_row4_col0,#T_701e5_row5_col0,#T_701e5_row6_col0,#T_701e5_row7_col0,#T_701e5_row8_col0,#T_701e5_row9_col0,#T_701e5_row10_col0,#T_701e5_row11_col0,#T_701e5_row12_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_701e5_row0_col2,#T_701e5_row1_col2,#T_701e5_row1_col3,#T_701e5_row1_col4,#T_701e5_row2_col2,#T_701e5_row2_col3,#T_701e5_row2_col6,#T_701e5_row3_col2,#T_701e5_row4_col2,#T_701e5_row4_col3,#T_701e5_row4_col6,#T_701e5_row5_col2,#T_701e5_row6_col2,#T_701e5_row7_col2,#T_701e5_row8_col2,#T_701e5_row9_col2,#T_701e5_row9_col3,#T_701e5_row9_col6,#T_701e5_row10_col2,#T_701e5_row11_col2,#T_701e5_row12_col2{
#             color:  black;
#         }#T_701e5_row0_col3,#T_701e5_row0_col4,#T_701e5_row6_col3,#T_701e5_row6_col4,#T_701e5_row7_col3,#T_701e5_row7_col4,#T_701e5_row8_col3,#T_701e5_row8_col4,#T_701e5_row11_col3,#T_701e5_row11_col4,#T_701e5_row12_col3,#T_701e5_row12_col4{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_701e5_row0_col6,#T_701e5_row6_col6,#T_701e5_row7_col6,#T_701e5_row8_col6,#T_701e5_row11_col6,#T_701e5_row12_col6{
#             background-color:  #84cc83;
#             color:  black;
#         }#T_701e5_row1_col1,#T_701e5_row4_col1,#T_701e5_row11_col1,#T_701e5_row12_col1{
#             color:  #790f8a;
#         }#T_701e5_row1_col6{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_701e5_row2_col4,#T_701e5_row4_col4,#T_701e5_row9_col4,#T_701e5_row10_col3,#T_701e5_row10_col4,#T_701e5_row10_col6{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_701e5_row3_col1,#T_701e5_row5_col1,#T_701e5_row6_col1{
#             color:  #0f398a;
#         }#T_701e5_row3_col3,#T_701e5_row3_col4{
#             background-color:  #fc9576;
#             color:  black;
#         }#T_701e5_row3_col6,#T_701e5_row5_col6{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_701e5_row5_col3,#T_701e5_row5_col4{
#             background-color:  #fcb499;
#             color:  black;
#         }</style><table id="T_701e5_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (13)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_701e5_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_701e5_row0_col0" class="data row0 col0" >activation_id</td>
#                         <td id="T_701e5_row0_col1" class="data row0 col1" >object</td>
#                         <td id="T_701e5_row0_col2" class="data row0 col2" >2.5%</td>
#                         <td id="T_701e5_row0_col3" class="data row0 col3" >83.4%</td>
#                                 <td id="T_701e5_row0_col5" class="data row0 col5" >1727</td>
#                         <td id="T_701e5_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_701e5_row0_col7" class="data row0 col7" >Sample: 5d0001a7-b61d-4d73-83f7-071eabb6312e | 9d0ae5a5-7783-44ec-bcb7-618478f748a4</td>
#             </tr>
#             <tr>
#                         <th id="T_701e5_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_701e5_row1_col0" class="data row1 col0" >feedback_dt</td>
#                         <td id="T_701e5_row1_col1" class="data row1 col1" >datetime64[ns]</td>
#                         <td id="T_701e5_row1_col2" class="data row1 col2" >0.0%</td>
#                         <td id="T_701e5_row1_col3" class="data row1 col3" >42.0%</td>
#                                 <td id="T_701e5_row1_col5" class="data row1 col5" >1727</td>
#                         <td id="T_701e5_row1_col6" class="data row1 col6" >5</td>
#                         <td id="T_701e5_row1_col7" class="data row1 col7" >max=2021-03-10 12:03:00 | min=2021-03-08 08:20:00 | yr mean= 2021</td>
#             </tr>
#             <tr>
#                         <th id="T_701e5_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_701e5_row2_col0" class="data row2 col0" >feedback_id</td>
#                         <td id="T_701e5_row2_col1" class="data row2 col1" >object</td>
#                         <td id="T_701e5_row2_col2" class="data row2 col2" >0.0%</td>
#                         <td id="T_701e5_row2_col3" class="data row2 col3" >0.1%</td>
#                                 <td id="T_701e5_row2_col5" class="data row2 col5" >1727</td>
#                         <td id="T_701e5_row2_col6" class="data row2 col6" >1727</td>
#                         <td id="T_701e5_row2_col7" class="data row2 col7" >Sample: 20210313001331 | 20210312184410 | 20210313060844 | 20210313023016 | 20210313015540</td>
#             </tr>
#             <tr>
#                         <th id="T_701e5_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_701e5_row3_col0" class="data row3 col0" >has_interacted</td>
#                         <td id="T_701e5_row3_col1" class="data row3 col1" >int64</td>
#                         <td id="T_701e5_row3_col2" class="data row3 col2" >0.0%</td>
#                         <td id="T_701e5_row3_col3" class="data row3 col3" >95.4%</td>
#                                 <td id="T_701e5_row3_col5" class="data row3 col5" >1727</td>
#                         <td id="T_701e5_row3_col6" class="data row3 col6" >2</td>
#                         <td id="T_701e5_row3_col7" class="data row3 col7" >max=1 | min=0 | mean=0.95 | dominant=1</td>
#             </tr>
#             <tr>
#                         <th id="T_701e5_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_701e5_row4_col0" class="data row4 col0" >has_interacted_dt</td>
#                         <td id="T_701e5_row4_col1" class="data row4 col1" >datetime64[ns]</td>
#                         <td id="T_701e5_row4_col2" class="data row4 col2" >4.6%</td>
#                         <td id="T_701e5_row4_col3" class="data row4 col3" >4.6%</td>
#                                 <td id="T_701e5_row4_col5" class="data row4 col5" >1727</td>
#                         <td id="T_701e5_row4_col6" class="data row4 col6" >1554</td>
#                         <td id="T_701e5_row4_col7" class="data row4 col7" >max=2021-03-10 12:02:23 | min=2021-03-08 06:50:06 | yr mean= 2021</td>
#             </tr>
#             <tr>
#                         <th id="T_701e5_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_701e5_row5_col0" class="data row5 col0" >has_permission</td>
#                         <td id="T_701e5_row5_col1" class="data row5 col1" >int64</td>
#                         <td id="T_701e5_row5_col2" class="data row5 col2" >0.0%</td>
#                         <td id="T_701e5_row5_col3" class="data row5 col3" >94.7%</td>
#                                 <td id="T_701e5_row5_col5" class="data row5 col5" >1727</td>
#                         <td id="T_701e5_row5_col6" class="data row5 col6" >2</td>
#                         <td id="T_701e5_row5_col7" class="data row5 col7" >max=1 | min=0 | mean=0.95 | dominant=1</td>
#             </tr>
#             <tr>
#                         <th id="T_701e5_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_701e5_row6_col0" class="data row6 col0" >intervention_cat</td>
#                         <td id="T_701e5_row6_col1" class="data row6 col1" >int64</td>
#                         <td id="T_70

# %% [markdown]
# ### Modify the watchlist

# %%
df['plan_id'] = tools.correlate_choice(df, header='plan_id', list_size=1, random_choice=False, column_name='plan_id')
builder.add_column_description(column_name='plan_id', description="temporary modification of the Plan id, taking only one id from the list")

# %%
df.intervention_id.value_counts()
# Out:
# Outreach nurse contacts high flu risk member                           1440
# Prompt member to call the nurseline for information about flu shots     243
# Do nothing                                                               44
# Name: intervention_id, dtype: int64

# %%
selection = ['Outreach nurse contacts high flu risk member',
             'Prompt member to call the nurseline for information about flu shots',
             'Do nothing']

df['intervention_cat'] = tools.correlate_categories(df, header='intervention_id', correlations=selection, actions={0: 1, 1: 2, 2: 3}, default_action=4, column_name='intervention_cat')
builder.add_column_description(column_name='intervention_cat', description="for clarity changing the intervention_id string to a numberic category")

# %% [markdown]
# **adjust watch start**

# %%
actions = {0: tools.action2dict(method='get_datetime', start=-4, until=-3, ignore_time=True, date_format="%Y-%m-%d %H:%M"),
           1: tools.action2dict(method='get_datetime', start=-3, until=-2, ignore_time=True, date_format="%Y-%m-%d %H:%M"),
           2: tools.action2dict(method='get_datetime', start=-2, until=-1, ignore_time=True, date_format="%Y-%m-%d %H:%M")}

df['watch_start'] = tools.correlate_categories(df, header='intervention_cat', correlations=[1, 2, 3], actions=actions, column_name='watch_start', intent_order=0)
builder.add_column_description(column_name='watch_start', description="modify the watch start to place it in the past")

# %%
actions = {0: tools.action2dict(method='correlate_dates', header='watch_start', offset={'hours':8, 'minutes': 20}),
           1: tools.action2dict(method='correlate_dates', header='watch_start', offset={'hours':12, 'minutes': 3}),
           2: tools.action2dict(method='correlate_dates', header='watch_start', offset={'hours':7, 'minutes': 31})}

df['watch_start'] = tools.correlate_categories(df, header='intervention_cat', correlations=[1, 2, 3], actions=actions, column_name='watch_start', intent_order=1)

# %% [markdown]
# **adjust watch end**

# %%
actions = {0: tools.action2dict(method='get_datetime', start=-1, until=0, ignore_time=True, date_format="%Y-%m-%d %H:%M"),
           1: tools.action2dict(method='get_datetime', start=-1, until=0, ignore_time=True, date_format="%Y-%m-%d %H:%M"),
           2: tools.action2dict(method='get_datetime', start=-1, until=0, ignore_time=True, date_format="%Y-%m-%d %H:%M")}

df['watch_stop'] = tools.correlate_categories(df, header='intervention_cat', correlations=[1, 2, 3], actions=actions, default_action='', column_name='watch_stop', intent_order=0)
builder.add_column_description(column_name='watch_stop', description="modify the watch end after the watch_start")

# %%
actions = {0: tools.action2dict(method='correlate_dates', header='watch_stop', offset={'hours':-7, 'minutes': 45}),
           1: tools.action2dict(method='correlate_dates', header='watch_stop', offset={'hours':-4, 'minutes': 3}),
           2: tools.action2dict(method='correlate_dates', header='watch_stop', offset={'hours':-1, 'minutes': 23})}

df['watch_stop'] = tools.correlate_categories(df, header='intervention_cat', correlations=[1, 2, 3], actions=actions, default_action='', column_name='watch_stop', intent_order=1)

# %% [markdown]
# ------------------------
# ### Feedback Date

# %%
actions = {0: tools.action2dict(method='correlate_dates', header='watch_start', jitter=3, jitter_units='D', jitter_freq=[0, 1]),
           1: tools.action2dict(method='correlate_dates', header='watch_start', jitter=2, jitter_units='D', jitter_freq=[0, 1]),
           2: tools.action2dict(method='correlate_dates', header='watch_start', jitter=1, jitter_units='D', jitter_freq=[0, 1])}

df['feedback_dt'] = tools.correlate_categories(df, header='intervention_cat', correlations=[1, 2, 3], actions=actions, column_name='feedback_dt')
builder.add_column_description(column_name='feedback_dt', description="The date when feedback was recieved")

# %% [markdown]
# ------------------------
# ### Add the gets

# %%
# feedback_id
df['feedback_id'] = tools.get_datetime(start=0, until=1, at_most=1, date_format="%Y%m%d%H%M%S", ordered='asc', size=sample_size, column_name='feedback_id')
builder.add_column_description(column_name='feedback_id', description="a unique reference id from the feedback system unique across all feeback batches")

# %%
df['has_permission'] = tools.get_category(selection=[1, 0], relative_freq=[20,1], size=sample_size, column_name='has_permission')
builder.add_column_description(column_name='has_permission', description="If the profile has their permissions set favourably for this intervention")

# %%
df['has_interacted'] = tools.get_category(selection=[1, 0], relative_freq=[40,1], size=sample_size, column_name='has_interacted', intent_order=0)
builder.add_column_description(column_name='has_interacted', description="If the member has interacted with the intervention, e.g. contacted, enacted upon an action or read a notification")

# %%
selection = [builder.tools.select2dict(column='intervention_cat', condition="@ == 3")]

default = builder.tools.action2dict(method='@header', header='has_interacted')

df['has_interacted'] = builder.tools.correlate_selection(df, selection=selection, action=0, default_action=default, column_name='has_interacted', intent_order=2)

# %%
# The date of the interaction
selection = [builder.tools.select2dict(column='has_interacted', condition="@ == 1")]

action = builder.tools.action2dict(method='correlate_dates', header='feedback_dt', jitter=3, jitter_units='h', jitter_freq=[1,0])
default = builder.tools.action2dict(method='@constant', value=np.nan)

df['has_interacted_dt'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='has_interacted_dt', intent_order=0)
builder.add_column_description(column_name='has_interacted_dt', description="a recorded date time when the recorded interaction occured")

# %% [markdown]
# ------------------

# %%
selection = ['Outreach nurse contacts high flu risk member',
             'Prompt member to call the nurseline for information about flu shots',
             'Do nothing']

actions = {0: 'CSS',
           1: 'SydneyCare',
           2: 'N/A'}

df['reporting_system'] = tools.correlate_categories(df, header='intervention_id', correlations=selection, actions=actions, column_name='reporting_system')
builder.add_column_description(column_name='reporting_system', description="The system that reported the feedback")

# %% [markdown]
# ------------------
# ### Inferred feedback

# %%
# if has interacted then if there is an observed action
df['inferred_change'] = builder.tools.correlate_selection(df, selection = [], action=0, default_action=0, column_name='inferred_change', intent_order=0)
builder.add_column_description(column_name='inferred_change', description="An inferred action on the intervention from a transitive system e.g. claim made")

# %%
# which channel the observed action was on
selection = [builder.tools.select2dict(column='inferred_change', condition="@ == 1")]

action = builder.tools.action2dict(method='get_category', selection=['claims', 'gov', 'external'], relative_freq=[1, 0.1, 0.01])

df['change_channel'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action='', column_name='change_channel', intent_order=0)
builder.add_column_description(column_name='change_channel', description="The channel from which the observation came")

# %%
# which channel the observed action was on
selection = [builder.tools.select2dict(column='inferred_change', condition="@ == 1")]

action = builder.tools.action2dict(method='correlate_dates', header='has_interacted_dt', offset=2, jitter=1, jitter_units='D', jitter_freq=[0, 1])

df['change_dt'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=np.nan, column_name='change_dt', intent_order=0)
builder.add_column_description(column_name='change_dt', description="The timestamp associated with the observed action")

# %% [markdown]
# ------------------

# %%
builder.report_intent(stylise=False)
# Out:
#                 level order                intent  \
# 0      change_channel     0   correlate_selection
# 1           change_dt     0   correlate_selection
# 2         feedback_dt     0  correlate_categories
# 3         feedback_id     0          get_datetime
# 4      has_interacted     0          get_category
# 5      has_interacted     2   correlate_selection
# 6   has_interacted_dt     0   correlate_selection
# 7      has_permission     0          get_category
# 8     inferred_change     0   correlate_selection
# 9    intervention_cat     0  correlate_categories
# 10            plan_id     0      correlate_choice
# 11   reporting_system     0  correlate_categories
# 12        watch_start     0  correlate_categories
# 13        watch_start     1  correlate_categories
# 14         watch_stop     0  correlate_categories
# 15         watch_stop     1  correlate_categories
# 16          watchlist     0         frame_starter
#
#                                                                                                                                                                                                  parameters  \
# 0   [selection=[{'column': 'inferred_change', 'condition': '@ == 1'}], action={'method': 'get_category', 'selection': ['claims', 'gov', 'external'], 'relative_freq': [1, 0.1, 0.01]}, default_action=''...
# 1   [selection=[{'column': 'inferred_change', 'condition': '@ == 1'}], action={'method': 'correlate_dates', 'header': 'has_interacted_dt', 'offset': 2, 'jitter': 1, 'jitter_units': 'D', 'jitter_freq':...
# 2   [header='intervention_cat', correlations=[1, 2, 3], actions={0: {'method': 'correlate_dates', 'header': 'watch_start', 'jitter': 3, 'jitter_units': 'D', 'jitter_freq': [0, 1]}, 1: {'method': 'corr...
# 3                                                                                                       [start=0, until=1, at_most=1, ordered='asc', date_format='%Y%m%d%H%M%S', column_name='feedback_id']
# 4                                                                                                                                   [selection=[1, 0], relative_freq=[40, 1], column_name='has_interacted']
# 5                             [selection=[{'column': 'intervention_cat', 'condition': '@ == 3'}], action=0, default_action={'method': '@header', 'header': 'has_interacted'}, column_name='has_interacted']
# 6   [selection=[{'column': 'has_interacted', 'condition': '@ == 1'}], action={'method': 'correlate_dates', 'header': 'feedback_dt', 'jitter': 3, 'jitter_units': 'h', 'jitter_freq': [1, 0]}, default_ac...
# 7                                                                                                                                   [selection=[1, 0], relative_freq=[20, 1], column_name='has_permission']
# 8                                                                                                                                 [selection=[], action=0, default_action=0, column_name='inferred_change']
# 9   [header='intervention_id', correlations=['Outreach nurse contacts high flu risk member', 'Prompt member to call the nurseline for information about flu shots', 'Do nothing'], actions={0: 1, 1: 2, ...
# 10                                                                                                                              [header='plan_id', list_size=1, random_choice=False, column_name='plan_id']
# 11  [header='intervention_id', correlations=['Outreach nurse contacts high flu risk member', 'Prompt member to call the nurseline for information about flu shots', 'Do nothing'], actions={0: 'CSS', 1:...
# 12  [header='intervention_cat', correlations=[1, 2, 3], actions={0: {'method': 'get_datetime', 'start': -4, 'until': -3, 'ignore_time': True, 'date_format': '%Y-%m-%d %H:%M'}, 1: {'method': 'get_datet...
# 13  [header='intervention_cat', correlations=[1, 2, 3], actions={0: {'method': 'correlate_dates', 'header': 'watch_start', 'offset': {'hours': 8, 'minutes': 20}}, 1: {'method': 'correlate_dates', 'hea...
# 14  [header='intervention_cat', correlations=[1, 2, 3], actions={0: {'method': 'get_datetime', 'start': -1, 'until': 0, 'ignore_time': True, 'date_format': '%Y-%m-%d %H:%M'}, 1: {'method': 'get_dateti...
# 15  [header='intervention_cat', correlations=[1, 2, 3], actions={0: {'method': 'correlate_dates', 'header': 'watch_stop', 'offset': {'hours': -7, 'minutes': 45}}, 1: {'method': 'correlate_dates', 'hea...
# 16                                                                                                                                                          [canonical='feedback', column_name='watchlist']
#
#       creator
# 0   doatridge
# 1   doatridge
# 2   doatridge
# 3   doatridge
# 4   doatridge
# 5   doatridge
# 6   doatridge
# 7   doatridge
# 8   doatridge
# 9   doatridge
# 10  doatridge
# 11  doatridge
# 12  doatridge
# 13  doatridge
# 14  doatridge
# 15  doatridge
# 16  doatridge

# %%
builder.canonical_report(df)
# Out:
# <style  type="text/css" >
#     #T_5fcd3_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_5fcd3_ .row_heading, .blank {
#           display: none;;
#     }#T_5fcd3_row0_col0,#T_5fcd3_row1_col0,#T_5fcd3_row2_col0,#T_5fcd3_row3_col0,#T_5fcd3_row4_col0,#T_5fcd3_row5_col0,#T_5fcd3_row6_col0,#T_5fcd3_row7_col0,#T_5fcd3_row8_col0,#T_5fcd3_row9_col0,#T_5fcd3_row10_col0,#T_5fcd3_row11_col0,#T_5fcd3_row12_col0,#T_5fcd3_row13_col0,#T_5fcd3_row14_col0,#T_5fcd3_row15_col0,#T_5fcd3_row16_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_5fcd3_row0_col2,#T_5fcd3_row2_col3,#T_5fcd3_row3_col2,#T_5fcd3_row3_col3,#T_5fcd3_row3_col4,#T_5fcd3_row4_col2,#T_5fcd3_row4_col3,#T_5fcd3_row4_col6,#T_5fcd3_row5_col2,#T_5fcd3_row6_col2,#T_5fcd3_row6_col3,#T_5fcd3_row6_col6,#T_5fcd3_row7_col2,#T_5fcd3_row8_col2,#T_5fcd3_row9_col2,#T_5fcd3_row10_col2,#T_5fcd3_row11_col2,#T_5fcd3_row12_col2,#T_5fcd3_row12_col3,#T_5fcd3_row12_col6,#T_5fcd3_row13_col2,#T_5fcd3_row14_col2,#T_5fcd3_row15_col2,#T_5fcd3_row16_col2{
#             color:  black;
#         }#T_5fcd3_row0_col3,#T_5fcd3_row0_col4,#T_5fcd3_row9_col3,#T_5fcd3_row9_col4,#T_5fcd3_row10_col3,#T_5fcd3_row10_col4,#T_5fcd3_row11_col3,#T_5fcd3_row11_col4,#T_5fcd3_row13_col3,#T_5fcd3_row13_col4,#T_5fcd3_row15_col3,#T_5fcd3_row15_col4,#T_5fcd3_row16_col3,#T_5fcd3_row16_col4{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_5fcd3_row0_col6,#T_5fcd3_row9_col6,#T_5fcd3_row10_col6,#T_5fcd3_row11_col6,#T_5fcd3_row13_col6,#T_5fcd3_row15_col6,#T_5fcd3_row16_col6{
#             background-color:  #84cc83;
#             color:  black;
#         }#T_5fcd3_row1_col2,#T_5fcd3_row1_col3,#T_5fcd3_row1_col4,#T_5fcd3_row1_col6,#T_5fcd3_row2_col2,#T_5fcd3_row2_col4,#T_5fcd3_row2_col6,#T_5fcd3_row4_col4,#T_5fcd3_row6_col4,#T_5fcd3_row8_col3,#T_5fcd3_row8_col4,#T_5fcd3_row8_col6,#T_5fcd3_row12_col4,#T_5fcd3_row14_col3,#T_5fcd3_row14_col4,#T_5fcd3_row14_col6{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_5fcd3_row2_col1{
#             color:  #2f0f8a;
#         }#T_5fcd3_row3_col1,#T_5fcd3_row6_col1,#T_5fcd3_row15_col1,#T_5fcd3_row16_col1{
#             color:  #790f8a;
#         }#T_5fcd3_row3_col6{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_5fcd3_row5_col1,#T_5fcd3_row7_col1,#T_5fcd3_row8_col1,#T_5fcd3_row9_col1{
#             color:  #0f398a;
#         }#T_5fcd3_row5_col3,#T_5fcd3_row5_col4{
#             background-color:  #fc9576;
#             color:  black;
#         }#T_5fcd3_row5_col6,#T_5fcd3_row7_col6{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_5fcd3_row7_col3,#T_5fcd3_row7_col4{
#             background-color:  #fcb499;
#             color:  black;
#         }</style><table id="T_5fcd3_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (17)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5fcd3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5fcd3_row0_col0" class="data row0 col0" >activation_id</td>
#                         <td id="T_5fcd3_row0_col1" class="data row0 col1" >object</td>
#                         <td id="T_5fcd3_row0_col2" class="data row0 col2" >2.5%</td>
#                         <td id="T_5fcd3_row0_col3" class="data row0 col3" >83.4%</td>
#                                 <td id="T_5fcd3_row0_col5" class="data row0 col5" >1727</td>
#                         <td id="T_5fcd3_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_5fcd3_row0_col7" class="data row0 col7" >Sample: 5d0001a7-b61d-4d73-83f7-071eabb6312e | 9d0ae5a5-7783-44ec-bcb7-618478f748a4</td>
#             </tr>
#             <tr>
#                         <th id="T_5fcd3_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5fcd3_row1_col0" class="data row1 col0" >change_channel</td>
#                         <td id="T_5fcd3_row1_col1" class="data row1 col1" >object</td>
#                         <td id="T_5fcd3_row1_col2" class="data row1 col2" >100.0%</td>
#                         <td id="T_5fcd3_row1_col3" class="data row1 col3" >100.0%</td>
#                                 <td id="T_5fcd3_row1_col5" class="data row1 col5" >1727</td>
#                         <td id="T_5fcd3_row1_col6" class="data row1 col6" >1</td>
#                         <td id="T_5fcd3_row1_col7" class="data row1 col7" >Sample: </td>
#             </tr>
#             <tr>
#                         <th id="T_5fcd3_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5fcd3_row2_col0" class="data row2 col0" >change_dt</td>
#                         <td id="T_5fcd3_row2_col1" class="data row2 col1" >float64</td>
#                         <td id="T_5fcd3_row2_col2" class="data row2 col2" >100.0%</td>
#                         <td id="T_5fcd3_row2_col3" class="data row2 col3" >0.0%</td>
#                                 <td id="T_5fcd3_row2_col5" class="data row2 col5" >1727</td>
#                         <td id="T_5fcd3_row2_col6" class="data row2 col6" >1</td>
#                         <td id="T_5fcd3_row2_col7" class="data row2 col7" >max=nan | min=nan | mean=nan | dominant=[]</td>
#             </tr>
#             <tr>
#                         <th id="T_5fcd3_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5fcd3_row3_col0" class="data row3 col0" >feedback_dt</td>
#                         <td id="T_5fcd3_row3_col1" class="data row3 col1" >datetime64[ns]</td>
#                         <td id="T_5fcd3_row3_col2" class="data row3 col2" >0.0%</td>
#                         <td id="T_5fcd3_row3_col3" class="data row3 col3" >42.0%</td>
#                                 <td id="T_5fcd3_row3_col5" class="data row3 col5" >1727</td>
#                         <td id="T_5fcd3_row3_col6" class="data row3 col6" >5</td>
#                         <td id="T_5fcd3_row3_col7" class="data row3 col7" >max=2021-03-10 12:03:00 | min=2021-03-08 08:20:00 | yr mean= 2021</td>
#             </tr>
#             <tr>
#                         <th id="T_5fcd3_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_5fcd3_row4_col0" class="data row4 col0" >feedback_id</td>
#                         <td id="T_5fcd3_row4_col1" class="data row4 col1" >object</td>
#                         <td id="T_5fcd3_row4_col2" class="data row4 col2" >0.0%</td>
#                         <td id="T_5fcd3_row4_col3" class="data row4 col3" >0.1%</td>
#                                 <td id="T_5fcd3_row4_col5" class="data row4 col5" >1727</td>
#                         <td id="T_5fcd3_row4_col6" class="data row4 col6" >1727</td>
#                         <td id="T_5fcd3_row4_col7" class="data row4 col7" >Sample: 20210313001331 | 20210312184410 | 20210313060844 | 20210313023016 | 20210313015540</td>
#             </tr>
#             <tr>
#                         <th id="T_5fcd3_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_5fcd3_row5_col0" class="data row5 col0" >has_interacted</td>
#                         <td id="T_5fcd3_row5_col1" class="data row5 col1" >int64</td>
#                         <td id="T_5fcd3_row5_col2" class="data row5 col2" >0.0%</td>
#                         <td id="T_5fcd3_row5_col3" class="data row5 col3" >95.4%</td>
#                                 <td id="T_5fcd3_row5_col5" class="data row5 col5" >1727</td>
#                         <td id="T_5fcd3_row5_col6" class="data row5 col6" >2</td>
#                         <td id="T_5fcd3_row5_col7" cla

# %%
tools.run_intent_pipeline(simulate=True)
# Out:
#                column order                method
# 0           watchlist     0         frame_starter
# 1         feedback_id     0          get_datetime
# 2      has_permission     0          get_category
# 3             plan_id     0      correlate_choice
# 4    intervention_cat     0  correlate_categories
# 5         watch_start     0  correlate_categories
# 6         watch_start     1  correlate_categories
# 7          watch_stop     0  correlate_categories
# 8          watch_stop     1  correlate_categories
# 9         feedback_dt     0  correlate_categories
# 10     has_interacted     0          get_category
# 11     has_interacted     2   correlate_selection
# 12  has_interacted_dt     0   correlate_selection
# 13   reporting_system     0  correlate_categories
# 14    inferred_change     0   correlate_selection
# 15     change_channel     0   correlate_selection
# 16          change_dt     0   correlate_selection

# %%
builder.run_component_pipeline(canonical='feedback')

# %%
builder.report_column_catalog()
# Out:
# <style  type="text/css" >
#     #T_cf793_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_cf793_ .row_heading, .blank {
#           display: none;;
#     }#T_cf793_row0_col0,#T_cf793_row1_col0,#T_cf793_row2_col0,#T_cf793_row3_col0,#T_cf793_row4_col0,#T_cf793_row5_col0,#T_cf793_row6_col0,#T_cf793_row7_col0,#T_cf793_row8_col0,#T_cf793_row9_col0,#T_cf793_row10_col0,#T_cf793_row11_col0,#T_cf793_row12_col0,#T_cf793_row13_col0{
#             text-align:  left;
#             font-weight:  bold;
#         }#T_cf793_row0_col1,#T_cf793_row1_col1,#T_cf793_row2_col1,#T_cf793_row3_col1,#T_cf793_row4_col1,#T_cf793_row5_col1,#T_cf793_row6_col1,#T_cf793_row7_col1,#T_cf793_row8_col1,#T_cf793_row9_col1,#T_cf793_row10_col1,#T_cf793_row11_col1,#T_cf793_row12_col1,#T_cf793_row13_col1{
#             text-align:  left;
#         }</style><table id="T_cf793_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >column_name</th>        <th class="col_heading level0 col1" >description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf793_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cf793_row0_col0" class="data row0 col0" >change_channel</td>
#                         <td id="T_cf793_row0_col1" class="data row0 col1" >The channel from which the observation came</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cf793_row1_col0" class="data row1 col0" >change_dt</td>
#                         <td id="T_cf793_row1_col1" class="data row1 col1" >The timestamp associated with the observed action</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_cf793_row2_col0" class="data row2 col0" >feedback_dt</td>
#                         <td id="T_cf793_row2_col1" class="data row2 col1" >The date when feedback was recieved</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_cf793_row3_col0" class="data row3 col0" >feedback_id</td>
#                         <td id="T_cf793_row3_col1" class="data row3 col1" >a unique reference id from the feedback system unique across all feeback batches</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_cf793_row4_col0" class="data row4 col0" >has_interacted</td>
#                         <td id="T_cf793_row4_col1" class="data row4 col1" >If the member has interacted with the intervention, e.g. contacted, enacted upon an action or read a notification</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_cf793_row5_col0" class="data row5 col0" >has_interacted_dt</td>
#                         <td id="T_cf793_row5_col1" class="data row5 col1" >a recorded date time when the recorded interaction occured</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_cf793_row6_col0" class="data row6 col0" >has_permission</td>
#                         <td id="T_cf793_row6_col1" class="data row6 col1" >If the profile has their permissions set favourably for this intervention</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_cf793_row7_col0" class="data row7 col0" >inferred_change</td>
#                         <td id="T_cf793_row7_col1" class="data row7 col1" >An inferred action on the intervention from a transitive system e.g. claim made</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_cf793_row8_col0" class="data row8 col0" >intervention_cat</td>
#                         <td id="T_cf793_row8_col1" class="data row8 col1" >for clarity changing the intervention_id string to a numberic category</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_cf793_row9_col0" class="data row9 col0" >plan_id</td>
#                         <td id="T_cf793_row9_col1" class="data row9 col1" >temporary modification of the Plan id, taking only one id from the list</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_cf793_row10_col0" class="data row10 col0" >reporting_system</td>
#                         <td id="T_cf793_row10_col1" class="data row10 col1" >The system that reported the feedback</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_cf793_row11_col0" class="data row11 col0" >watch_start</td>
#                         <td id="T_cf793_row11_col1" class="data row11 col1" >modify the watch start to place it in the past</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_cf793_row12_col0" class="data row12 col0" >watch_stop</td>
#                         <td id="T_cf793_row12_col1" class="data row12 col1" >modify the watch end after the watch_start</td>
#             </tr>
#             <tr>
#                         <th id="T_cf793_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_cf793_row13_col0" class="data row13 col0" >watchlist</td>
#                         <td id="T_cf793_row13_col1" class="data row13 col1" >extracted watchlist from the plan executor</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# -------------------------
# -------------------------
# ## Intervention Feedback

# %%
tr = Transition.from_env('feedback')

# %%
tr.pm.reset_intents()
tr.pm_persist()

# %%
df = tr.load_source_canonical()

# %%
df = tr.intent_model.auto_clean_header(df, rename_map={'member_id': 'profile_id'})
df = tr.intent_model.auto_transition(df)
df = tr.intent_model.to_remove(df, regex=['watch_', 'intervention_cat'])

# %%
tr.upload_attributes(builder.report_column_catalog(stylise=False), label_key='column_name', text_key='description', constraints=list(df.columns))

# %% [markdown]
# ## Run the Pipeline  save the Schema and show the Schema Report

# %%
# run the pipeline
tr.run_component_pipeline()

# report the canonical
tr.canonical_report(df)
# Out:
# <style  type="text/css" >
#     #T_2ee3d_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_2ee3d_ .row_heading, .blank {
#           display: none;;
#     }#T_2ee3d_row0_col0,#T_2ee3d_row1_col0,#T_2ee3d_row2_col0,#T_2ee3d_row3_col0,#T_2ee3d_row4_col0,#T_2ee3d_row5_col0,#T_2ee3d_row6_col0,#T_2ee3d_row7_col0,#T_2ee3d_row8_col0,#T_2ee3d_row9_col0,#T_2ee3d_row10_col0,#T_2ee3d_row11_col0,#T_2ee3d_row12_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_2ee3d_row0_col1,#T_2ee3d_row1_col1,#T_2ee3d_row3_col1,#T_2ee3d_row8_col1,#T_2ee3d_row9_col1,#T_2ee3d_row10_col1,#T_2ee3d_row12_col1{
#             color:  #208a0f;
#         }#T_2ee3d_row0_col2,#T_2ee3d_row1_col2,#T_2ee3d_row2_col3,#T_2ee3d_row3_col2,#T_2ee3d_row3_col3,#T_2ee3d_row3_col4,#T_2ee3d_row4_col2,#T_2ee3d_row4_col3,#T_2ee3d_row4_col6,#T_2ee3d_row5_col2,#T_2ee3d_row6_col2,#T_2ee3d_row6_col3,#T_2ee3d_row6_col6,#T_2ee3d_row7_col2,#T_2ee3d_row8_col2,#T_2ee3d_row9_col2,#T_2ee3d_row10_col2,#T_2ee3d_row11_col2,#T_2ee3d_row11_col3,#T_2ee3d_row11_col6,#T_2ee3d_row12_col2{
#             color:  black;
#         }#T_2ee3d_row0_col3,#T_2ee3d_row0_col4,#T_2ee3d_row9_col3,#T_2ee3d_row9_col4,#T_2ee3d_row10_col3,#T_2ee3d_row10_col4,#T_2ee3d_row12_col3,#T_2ee3d_row12_col4{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_2ee3d_row0_col6,#T_2ee3d_row9_col6,#T_2ee3d_row10_col6,#T_2ee3d_row12_col6{
#             background-color:  #84cc83;
#             color:  black;
#         }#T_2ee3d_row1_col3,#T_2ee3d_row1_col4,#T_2ee3d_row1_col6,#T_2ee3d_row2_col2,#T_2ee3d_row2_col4,#T_2ee3d_row2_col6,#T_2ee3d_row4_col4,#T_2ee3d_row6_col4,#T_2ee3d_row8_col3,#T_2ee3d_row8_col4,#T_2ee3d_row8_col6,#T_2ee3d_row11_col4{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_2ee3d_row2_col1,#T_2ee3d_row6_col1{
#             color:  #790f8a;
#         }#T_2ee3d_row3_col6{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_2ee3d_row4_col1,#T_2ee3d_row11_col1{
#             color:  #0f398a;
#         }#T_2ee3d_row5_col1,#T_2ee3d_row7_col1{
#             color:  #08488e;
#         }#T_2ee3d_row5_col3,#T_2ee3d_row5_col4,#T_2ee3d_row7_col4{
#             background-color:  #fcb499;
#             color:  black;
#         }#T_2ee3d_row5_col6,#T_2ee3d_row7_col6{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_2ee3d_row7_col3{
#             background-color:  #fc9576;
#             color:  black;
#         }</style><table id="T_2ee3d_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (13)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2ee3d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2ee3d_row0_col0" class="data row0 col0" >activation_id</td>
#                         <td id="T_2ee3d_row0_col1" class="data row0 col1" >category</td>
#                         <td id="T_2ee3d_row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_2ee3d_row0_col3" class="data row0 col3" >83.4%</td>
#                                 <td id="T_2ee3d_row0_col5" class="data row0 col5" >1727</td>
#                         <td id="T_2ee3d_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_2ee3d_row0_col7" class="data row0 col7" >Sample: 5d0001a7-b61d-4d73-83f7-071eabb6312e | 9d0ae5a5-7783-44ec-bcb7-618478f748a4 | None</td>
#             </tr>
#             <tr>
#                         <th id="T_2ee3d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2ee3d_row1_col0" class="data row1 col0" >change_channel</td>
#                         <td id="T_2ee3d_row1_col1" class="data row1 col1" >category</td>
#                         <td id="T_2ee3d_row1_col2" class="data row1 col2" >0.0%</td>
#                         <td id="T_2ee3d_row1_col3" class="data row1 col3" >100.0%</td>
#                                 <td id="T_2ee3d_row1_col5" class="data row1 col5" >1727</td>
#                         <td id="T_2ee3d_row1_col6" class="data row1 col6" >1</td>
#                         <td id="T_2ee3d_row1_col7" class="data row1 col7" >Sample: nan</td>
#             </tr>
#             <tr>
#                         <th id="T_2ee3d_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2ee3d_row2_col0" class="data row2 col0" >change_dt</td>
#                         <td id="T_2ee3d_row2_col1" class="data row2 col1" >datetime64[ns]</td>
#                         <td id="T_2ee3d_row2_col2" class="data row2 col2" >100.0%</td>
#                         <td id="T_2ee3d_row2_col3" class="data row2 col3" >0.0%</td>
#                                 <td id="T_2ee3d_row2_col5" class="data row2 col5" >1727</td>
#                         <td id="T_2ee3d_row2_col6" class="data row2 col6" >1</td>
#                         <td id="T_2ee3d_row2_col7" class="data row2 col7" >max=NaT | min=NaT | yr mean= nan</td>
#             </tr>
#             <tr>
#                         <th id="T_2ee3d_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2ee3d_row3_col0" class="data row3 col0" >feedback_dt</td>
#                         <td id="T_2ee3d_row3_col1" class="data row3 col1" >category</td>
#                         <td id="T_2ee3d_row3_col2" class="data row3 col2" >0.0%</td>
#                         <td id="T_2ee3d_row3_col3" class="data row3 col3" >42.4%</td>
#                                 <td id="T_2ee3d_row3_col5" class="data row3 col5" >1727</td>
#                         <td id="T_2ee3d_row3_col6" class="data row3 col6" >5</td>
#                         <td id="T_2ee3d_row3_col7" class="data row3 col7" >Sample: 2021-03-09 08:20:00 | 2021-03-08 08:20:00 | 2021-03-10 12:03:00 | 2021-03-09 12:03:00 | 2021...</td>
#             </tr>
#             <tr>
#                         <th id="T_2ee3d_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2ee3d_row4_col0" class="data row4 col0" >feedback_id</td>
#                         <td id="T_2ee3d_row4_col1" class="data row4 col1" >int64</td>
#                         <td id="T_2ee3d_row4_col2" class="data row4 col2" >0.0%</td>
#                         <td id="T_2ee3d_row4_col3" class="data row4 col3" >0.1%</td>
#                                 <td id="T_2ee3d_row4_col5" class="data row4 col5" >1727</td>
#                         <td id="T_2ee3d_row4_col6" class="data row4 col6" >1727</td>
#                         <td id="T_2ee3d_row4_col7" class="data row4 col7" >max=20210313075030 | min=20210312075235 | mean=20210312451121.84 | dominant=[20210312075235, 20210312075300]</td>
#             </tr>
#             <tr>
#                         <th id="T_2ee3d_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2ee3d_row5_col0" class="data row5 col0" >has_interacted</td>
#                         <td id="T_2ee3d_row5_col1" class="data row5 col1" >bool</td>
#                         <td id="T_2ee3d_row5_col2" class="data row5 col2" >0.0%</td>
#                         <td id="T_2ee3d_row5_col3" class="data row5 col3" >94.7%</td>
#                                 <td id="T_2ee3d_row5_col5" class="data row5 col5" >1727</td>
#                         <td id="T_2ee3d_row5_col6" class="data row5 col6" >2</td>
#                         <td id="T_2ee3d_row5_col7" class="data row5 col7" >False | True</td>
#             </tr>
#             <tr>
#                         <th id="T_2ee3d_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2ee3d_row6_col0" class="da

# %%
tr.report_attributes(df)
# Out:
# <style  type="text/css" >
#     #T_78ee7_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_78ee7_ .row_heading, .blank {
#           display: none;;
#     }#T_78ee7_row0_col0,#T_78ee7_row1_col0,#T_78ee7_row2_col0,#T_78ee7_row3_col0,#T_78ee7_row4_col0,#T_78ee7_row5_col0,#T_78ee7_row6_col0,#T_78ee7_row7_col0,#T_78ee7_row8_col0,#T_78ee7_row9_col0,#T_78ee7_row10_col0,#T_78ee7_row11_col0,#T_78ee7_row12_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_78ee7_row0_col1,#T_78ee7_row1_col1,#T_78ee7_row3_col1,#T_78ee7_row8_col1,#T_78ee7_row9_col1,#T_78ee7_row10_col1,#T_78ee7_row12_col1{
#             color:  #208a0f;
#         }#T_78ee7_row0_col2,#T_78ee7_row1_col2,#T_78ee7_row2_col2,#T_78ee7_row3_col2,#T_78ee7_row4_col2,#T_78ee7_row5_col2,#T_78ee7_row6_col2,#T_78ee7_row7_col2,#T_78ee7_row8_col2,#T_78ee7_row9_col2,#T_78ee7_row10_col2,#T_78ee7_row11_col2,#T_78ee7_row12_col2{
#             text-align:  left;
#         }#T_78ee7_row2_col1,#T_78ee7_row6_col1{
#             color:  #790f8a;
#         }#T_78ee7_row4_col1,#T_78ee7_row11_col1{
#             color:  #0f398a;
#         }#T_78ee7_row5_col1,#T_78ee7_row7_col1{
#             color:  #08488e;
#         }</style><table id="T_78ee7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (13)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_78ee7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_78ee7_row0_col0" class="data row0 col0" >activation_id</td>
#                         <td id="T_78ee7_row0_col1" class="data row0 col1" >category</td>
#                         <td id="T_78ee7_row0_col2" class="data row0 col2" ></td>
#             </tr>
#             <tr>
#                         <th id="T_78ee7_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_78ee7_row1_col0" class="data row1 col0" >change_channel</td>
#                         <td id="T_78ee7_row1_col1" class="data row1 col1" >category</td>
#                         <td id="T_78ee7_row1_col2" class="data row1 col2" >The channel from which the observation came</td>
#             </tr>
#             <tr>
#                         <th id="T_78ee7_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_78ee7_row2_col0" class="data row2 col0" >change_dt</td>
#                         <td id="T_78ee7_row2_col1" class="data row2 col1" >datetime64[ns]</td>
#                         <td id="T_78ee7_row2_col2" class="data row2 col2" >The timestamp associated with the observed action</td>
#             </tr>
#             <tr>
#                         <th id="T_78ee7_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_78ee7_row3_col0" class="data row3 col0" >feedback_dt</td>
#                         <td id="T_78ee7_row3_col1" class="data row3 col1" >category</td>
#                         <td id="T_78ee7_row3_col2" class="data row3 col2" >The date when feedback was recieved</td>
#             </tr>
#             <tr>
#                         <th id="T_78ee7_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_78ee7_row4_col0" class="data row4 col0" >feedback_id</td>
#                         <td id="T_78ee7_row4_col1" class="data row4 col1" >int64</td>
#                         <td id="T_78ee7_row4_col2" class="data row4 col2" >a unique reference id from the feedback system unique across all feeback batches</td>
#             </tr>
#             <tr>
#                         <th id="T_78ee7_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_78ee7_row5_col0" class="data row5 col0" >has_interacted</td>
#                         <td id="T_78ee7_row5_col1" class="data row5 col1" >bool</td>
#                         <td id="T_78ee7_row5_col2" class="data row5 col2" >If the member has interacted with the intervention, e.g. contacted, enacted upon an action or read a notification</td>
#             </tr>
#             <tr>
#                         <th id="T_78ee7_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_78ee7_row6_col0" class="data row6 col0" >has_interacted_dt</td>
#                         <td id="T_78ee7_row6_col1" class="data row6 col1" >datetime64[ns]</td>
#                         <td id="T_78ee7_row6_col2" class="data row6 col2" >a recorded date time when the recorded interaction occured</td>
#             </tr>
#             <tr>
#                         <th id="T_78ee7_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_78ee7_row7_col0" class="data row7 col0" >has_permission</td>
#                         <td id="T_78ee7_row7_col1" class="data row7 col1" >bool</td>
#                         <td id="T_78ee7_row7_col2" class="data row7 col2" >If the profile has their permissions set favourably for this intervention</td>
#             </tr>
#             <tr>
#                         <th id="T_78ee7_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_78ee7_row8_col0" class="data row8 col0" >inferred_change</td>
#                         <td id="T_78ee7_row8_col1" class="data row8 col1" >category</td>
#                         <td id="T_78ee7_row8_col2" class="data row8 col2" >An inferred action on the intervention from a transitive system e.g. claim made</td>
#             </tr>
#             <tr>
#                         <th id="T_78ee7_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_78ee7_row9_col0" class="data row9 col0" >intervention_id</td>
#                         <td id="T_78ee7_row9_col1" class="data row9 col1" >category</td>
#                         <td id="T_78ee7_row9_col2" class="data row9 col2" ></td>
#             </tr>
#             <tr>
#                         <th id="T_78ee7_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_78ee7_row10_col0" class="data row10 col0" >plan_id</td>
#                         <td id="T_78ee7_row10_col1" class="data row10 col1" >category</td>
#                         <td id="T_78ee7_row10_col2" class="data row10 col2" >temporary modification of the Plan id, taking only one id from the list</td>
#             </tr>
#             <tr>
#                         <th id="T_78ee7_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_78ee7_row11_col0" class="data row11 col0" >profile_id</td>
#                         <td id="T_78ee7_row11_col1" class="data row11 col1" >int64</td>
#                         <td id="T_78ee7_row11_col2" class="data row11 col2" ></td>
#             </tr>
#             <tr>
#                         <th id="T_78ee7_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_78ee7_row12_col0" class="data row12 col0" >reporting_system</td>
#                         <td id="T_78ee7_row12_col1" class="data row12 col1" >category</td>
#                         <td id="T_78ee7_row12_col2" class="data row12 col2" >The system that reported the feedback</td>
#             </tr>
#     </tbody></table>
