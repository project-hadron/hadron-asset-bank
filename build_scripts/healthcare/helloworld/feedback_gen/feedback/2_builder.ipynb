# %%
# %run task_setup.ipynb
# Out:
# Foundation: 2.11.030
# Transition: 3.02.034

# %% [markdown]
# -------------------------
# ## Build Feedback synthetic file

# %%
builder = SyntheticBuilder.from_env('feedback')

# %%
tools = builder.intent_model

# %%
builder.pm.reset_intents()
builder.pm_persist()

# %% [markdown]
# ------------------------
# ### Load the watchlist

# %%
builder.add_connector_uri(connector_name='feedback', uri="s3://project-hadron-cs-repo/domain/helloworld/data/feedback/watchlist/${PLAN_WATCHLIST}", template_aligned=False)

# %%
df = tools.frame_starter(canonical='feedback', column_name='watchlist')
builder.add_column_description(column_name='watchlist', description="extracted watchlist from the plan executor")

# %%
sample_size = df.shape[0]

# %%
builder.canonical_report(df)
# Out:
# <style  type="text/css" >
#     #T_b03ac_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_b03ac_ .row_heading, .blank {
#           display: none;;
#     }#T_b03ac_row0_col0,#T_b03ac_row1_col0,#T_b03ac_row2_col0,#T_b03ac_row3_col0,#T_b03ac_row4_col0,#T_b03ac_row5_col0,#T_b03ac_row6_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_b03ac_row0_col2,#T_b03ac_row1_col2,#T_b03ac_row2_col2,#T_b03ac_row3_col2,#T_b03ac_row3_col3,#T_b03ac_row3_col6,#T_b03ac_row4_col2,#T_b03ac_row5_col2,#T_b03ac_row6_col2{
#             color:  black;
#         }#T_b03ac_row0_col3,#T_b03ac_row0_col4,#T_b03ac_row1_col3,#T_b03ac_row1_col4,#T_b03ac_row2_col3,#T_b03ac_row2_col4,#T_b03ac_row5_col3,#T_b03ac_row5_col4,#T_b03ac_row6_col3,#T_b03ac_row6_col4{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_b03ac_row0_col6,#T_b03ac_row1_col6,#T_b03ac_row2_col6,#T_b03ac_row5_col6,#T_b03ac_row6_col6{
#             background-color:  #84cc83;
#             color:  black;
#         }#T_b03ac_row3_col4,#T_b03ac_row4_col3,#T_b03ac_row4_col4,#T_b03ac_row4_col6{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_b03ac_row5_col1,#T_b03ac_row6_col1{
#             color:  #790f8a;
#         }</style><table id="T_b03ac_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (7)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b03ac_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b03ac_row0_col0" class="data row0 col0" >activation_id</td>
#                         <td id="T_b03ac_row0_col1" class="data row0 col1" >object</td>
#                         <td id="T_b03ac_row0_col2" class="data row0 col2" >2.5%</td>
#                         <td id="T_b03ac_row0_col3" class="data row0 col3" >83.4%</td>
#                                 <td id="T_b03ac_row0_col5" class="data row0 col5" >1727</td>
#                         <td id="T_b03ac_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_b03ac_row0_col7" class="data row0 col7" >Sample: 5d0001a7-b61d-4d73-83f7-071eabb6312e | 9d0ae5a5-7783-44ec-bcb7-618478f748a4</td>
#             </tr>
#             <tr>
#                         <th id="T_b03ac_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b03ac_row1_col0" class="data row1 col0" >intervention_id</td>
#                         <td id="T_b03ac_row1_col1" class="data row1 col1" >object</td>
#                         <td id="T_b03ac_row1_col2" class="data row1 col2" >0.0%</td>
#                         <td id="T_b03ac_row1_col3" class="data row1 col3" >83.4%</td>
#                                 <td id="T_b03ac_row1_col5" class="data row1 col5" >1727</td>
#                         <td id="T_b03ac_row1_col6" class="data row1 col6" >3</td>
#                         <td id="T_b03ac_row1_col7" class="data row1 col7" >Sample: Outreach nurse contacts high flu risk member | Prompt member to call the nurseline for infor...</td>
#             </tr>
#             <tr>
#                         <th id="T_b03ac_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b03ac_row2_col0" class="data row2 col0" >plan_id</td>
#                         <td id="T_b03ac_row2_col1" class="data row2 col1" >object</td>
#                         <td id="T_b03ac_row2_col2" class="data row2 col2" >0.0%</td>
#                         <td id="T_b03ac_row2_col3" class="data row2 col3" >83.4%</td>
#                                 <td id="T_b03ac_row2_col5" class="data row2 col5" >1727</td>
#                         <td id="T_b03ac_row2_col6" class="data row2 col6" >3</td>
#                         <td id="T_b03ac_row2_col7" class="data row2 col7" >Sample: ['ZvJqpKwGV1' '9jqVgsoBeR' '9jqVdT45eR' 'Ga5Zds8qON' '9wDNs8tmBA'
#  'wWEs1F7tnB' 'wErsmfotVq'...</td>
#             </tr>
#             <tr>
#                         <th id="T_b03ac_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b03ac_row3_col0" class="data row3 col0" >profile_id</td>
#                         <td id="T_b03ac_row3_col1" class="data row3 col1" >object</td>
#                         <td id="T_b03ac_row3_col2" class="data row3 col2" >0.0%</td>
#                         <td id="T_b03ac_row3_col3" class="data row3 col3" >0.3%</td>
#                                 <td id="T_b03ac_row3_col5" class="data row3 col5" >1727</td>
#                         <td id="T_b03ac_row3_col6" class="data row3 col6" >968</td>
#                         <td id="T_b03ac_row3_col7" class="data row3 col7" >Sample: 105849998 | 134568991 | 143595989 | 122981494 | 131819492</td>
#             </tr>
#             <tr>
#                         <th id="T_b03ac_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b03ac_row4_col0" class="data row4 col0" >watch_contract</td>
#                         <td id="T_b03ac_row4_col1" class="data row4 col1" >object</td>
#                         <td id="T_b03ac_row4_col2" class="data row4 col2" >0.0%</td>
#                         <td id="T_b03ac_row4_col3" class="data row4 col3" >100.0%</td>
#                                 <td id="T_b03ac_row4_col5" class="data row4 col5" >1727</td>
#                         <td id="T_b03ac_row4_col6" class="data row4 col6" >1</td>
#                         <td id="T_b03ac_row4_col7" class="data row4 col7" >Sample: ABC</td>
#             </tr>
#             <tr>
#                         <th id="T_b03ac_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b03ac_row5_col0" class="data row5 col0" >watch_start</td>
#                         <td id="T_b03ac_row5_col1" class="data row5 col1" >datetime64[ns]</td>
#                         <td id="T_b03ac_row5_col2" class="data row5 col2" >0.0%</td>
#                         <td id="T_b03ac_row5_col3" class="data row5 col3" >83.4%</td>
#                                 <td id="T_b03ac_row5_col5" class="data row5 col5" >1727</td>
#                         <td id="T_b03ac_row5_col6" class="data row5 col6" >3</td>
#                         <td id="T_b03ac_row5_col7" class="data row5 col7" >max=2021-03-09 15:20:02.445625 | min=2021-03-09 15:19:58.963942 | yr mean= 2021</td>
#             </tr>
#             <tr>
#                         <th id="T_b03ac_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b03ac_row6_col0" class="data row6 col0" >watch_stop</td>
#                         <td id="T_b03ac_row6_col1" class="data row6 col1" >datetime64[ns]</td>
#                         <td id="T_b03ac_row6_col2" class="data row6 col2" >0.0%</td>
#                         <td id="T_b03ac_row6_col3" class="data row6 col3" >83.4%</td>
#                                 <td id="T_b03ac_row6_col5" class="data row6 col5" >1727</td>
#                         <td id="T_b03ac_row6_col6" class="data row6 col6" >3</td>
#                         <td id="T_b03ac_row6_col7" class="data row6 col7" >max=2021-03-09 17:20:01.421872 | min=2021-03-09 15:19:58.963948 | yr mean= 2021</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Modify the watchlist

# %%
df['plan_id'] = tools.correlate_choice(df, header='plan_id', list_size=1, random_choice=False, column_name='plan_id')
builder.add_column_description(column_name='plan_id', description="temporary modification of the Plan id, taking only one id from the list")

# %%
df.intervention_id.value_counts()
# Out:
# Outreach nurse contacts high flu risk member                           1440
# Prompt member to call the nurseline for information about flu shots     243
# Do nothing                                                               44
# Name: intervention_id, dtype: int64

# %%
selection = ['Outreach nurse contacts high flu risk member',
             'Prompt member to call the nurseline for information about flu shots',
             'Do nothing']

df['intervention_cat'] = tools.correlate_categories(df, header='intervention_id', correlations=selection, actions={0: 1, 1: 2, 2: 3}, default_action=4, column_name='intervention_cat')
builder.add_column_description(column_name='intervention_cat', description="for clarity changing the intervention_id string to a numberic category")

# %% [markdown]
# **adjust watch start**

# %%
actions = {0: tools.action2dict(method='get_datetime', start=-4, until=-3, ignore_time=True, date_format="%Y-%m-%d %H:%M"),
           1: tools.action2dict(method='get_datetime', start=-3, until=-2, ignore_time=True, date_format="%Y-%m-%d %H:%M"),
           2: tools.action2dict(method='get_datetime', start=-2, until=-1, ignore_time=True, date_format="%Y-%m-%d %H:%M")}

df['watch_start'] = tools.correlate_categories(df, header='intervention_cat', correlations=[1, 2, 3], actions=actions, column_name='watch_start', intent_order=0)
builder.add_column_description(column_name='watch_start', description="modify the watch start to place it in the past")

# %%
actions = {0: tools.action2dict(method='correlate_dates', header='watch_start', offset={'hours':8, 'minutes': 20}),
           1: tools.action2dict(method='correlate_dates', header='watch_start', offset={'hours':12, 'minutes': 3}),
           2: tools.action2dict(method='correlate_dates', header='watch_start', offset={'hours':7, 'minutes': 31})}

df['watch_start'] = tools.correlate_categories(df, header='intervention_cat', correlations=[1, 2, 3], actions=actions, column_name='watch_start', intent_order=1)

# %% [markdown]
# **adjust watch end**

# %%
actions = {0: tools.action2dict(method='get_datetime', start=-1, until=0, ignore_time=True, date_format="%Y-%m-%d %H:%M"),
           1: tools.action2dict(method='get_datetime', start=-1, until=0, ignore_time=True, date_format="%Y-%m-%d %H:%M"),
           2: tools.action2dict(method='get_datetime', start=-1, until=0, ignore_time=True, date_format="%Y-%m-%d %H:%M")}

df['watch_stop'] = tools.correlate_categories(df, header='intervention_cat', correlations=[1, 2, 3], actions=actions, default_action='', column_name='watch_stop', intent_order=0)
builder.add_column_description(column_name='watch_stop', description="modify the watch end after the watch_start")

# %%
actions = {0: tools.action2dict(method='correlate_dates', header='watch_stop', offset={'hours':-7, 'minutes': 45}),
           1: tools.action2dict(method='correlate_dates', header='watch_stop', offset={'hours':-4, 'minutes': 3}),
           2: tools.action2dict(method='correlate_dates', header='watch_stop', offset={'hours':-1, 'minutes': 23})}

df['watch_stop'] = tools.correlate_categories(df, header='intervention_cat', correlations=[1, 2, 3], actions=actions, default_action='', column_name='watch_stop', intent_order=1)

# %% [markdown]
# ------------------------
# ### Feedback Date

# %%
actions = {0: tools.action2dict(method='correlate_dates', header='watch_start', jitter=3, jitter_units='D', jitter_freq=[0, 1]),
           1: tools.action2dict(method='correlate_dates', header='watch_start', jitter=2, jitter_units='D', jitter_freq=[0, 1]),
           2: tools.action2dict(method='correlate_dates', header='watch_start', jitter=1, jitter_units='D', jitter_freq=[0, 1])}

df['feedback_dt'] = tools.correlate_categories(df, header='intervention_cat', correlations=[1, 2, 3], actions=actions, column_name='feedback_dt')
builder.add_column_description(column_name='feedback_dt', description="The date when feedback was recieved")

# %% [markdown]
# ------------------------
# ### Add the gets

# %%
# feedback_id
df['feedback_id'] = tools.get_datetime(start=0, until=1, at_most=1, date_format="%Y%m%d%H%M%S", ordered='asc', size=sample_size, column_name='feedback_id')
builder.add_column_description(column_name='feedback_id', description="a unique reference id from the feedback system unique across all feeback batches")

# %%
df['action_success'] = tools.get_category(selection=[1, 0], relative_freq=[99,1], size=sample_size, column_name='action_success')
builder.add_column_description(column_name='action_success', description="If the profile has their permissions set favourably for this intervention")

# %%
df['action_reward'] = tools.get_category(selection=[1, 0], relative_freq=[40,1], size=sample_size, column_name='action_reward', intent_order=0)
builder.add_column_description(column_name='action_reward', description="If the member has interacted with the intervention, e.g. contacted, enacted upon an action or read a notification")

# %%
selection = [builder.tools.select2dict(column='intervention_cat', condition="@ == 3"),
             builder.tools.select2dict(column='action_success', condition="@ == 0", logic='OR')]

action = builder.tools.action2dict(method='@constant', value=0)
default = builder.tools.action2dict(method='@header', header='action_reward')

df['action_reward'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='action_reward', intent_order=1)

# %%
# The date of the interaction
selection = [builder.tools.select2dict(column='action_reward', condition="@ == 1")]

action = builder.tools.action2dict(method='correlate_dates', header='feedback_dt', jitter=3, jitter_units='h', jitter_freq=[1,0])
default = builder.tools.action2dict(method='@constant', value=np.nan)

df['action_reward_dt'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='action_reward_dt')
builder.add_column_description(column_name='action_reward_dt', description="a recorded date time when the recorded interaction occured")

# %% [markdown]
# ------------------

# %%
selection = ['Outreach nurse contacts high flu risk member',
             'Prompt member to call the nurseline for information about flu shots',
             'Do nothing']

actions = {0: 'CSS',
           1: 'SydneyCare',
           2: 'N/A'}

df['reporting_system'] = tools.correlate_categories(df, header='intervention_id', correlations=selection, actions=actions, column_name='reporting_system')
builder.add_column_description(column_name='reporting_system', description="The system that reported the feedback")

# %% [markdown]
# ------------------
# ### Inferred feedback

# %%
# if has interacted then if there is an observed action
selection = [builder.tools.select2dict(column='action_reward', condition="@ == 1")]

action = builder.tools.action2dict(method='get_category', selection=[1, 0], relative_freq=[0.001,1])
default = builder.tools.action2dict(method='@constant', value=0)

df['inferred_reward'] = builder.tools.correlate_selection(df, selection = selection, action=action, default_action=default, column_name='inferred_reward', intent_order=0)
builder.add_column_description(column_name='inferred_reward', description="a signal to indicate the ")

# %%
# which channel the observed action was on
selection = [builder.tools.select2dict(column='inferred_reward', condition="@ == 1")]

action = builder.tools.action2dict(method='get_number', from_value=0, to_value=1.0, precision=2, relative_freq=[0.01, 0.01, 0.1, 1, 3, 2, 0.1])
default = builder.tools.action2dict(method='@constant', value=0)

df['inferred_causation'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='inferred_causation', intent_order=0)
builder.add_column_description(column_name='inferred_causation', description="a confidence value of the inferred causation of the action to the reward")

# %%
# which channel the observed action was on
selection = [builder.tools.select2dict(column='inferred_reward', condition="@ == 1")]

action = builder.tools.action2dict(method='get_category', selection=['BI systems', 'Claims', 'Remmitance', 'Contact Center Systems', 'Government', 'External', 'Others'],  relative_freq=[4, 2, 2, 1, 0.5, 0.1, 0.01])

df['inferred_channel'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action='N/A', column_name='inferred_channel', intent_order=0)
builder.add_column_description(column_name='inferred_channel', description="The channel from which the observation came")

# %%
# which channel the observed action was on
selection = [builder.tools.select2dict(column='inferred_reward', condition="@ == 1")]

action = builder.tools.action2dict(method='correlate_dates', header='action_reward_dt', offset=1, jitter=1, jitter_units='D', jitter_freq=[0, 1])
default = builder.tools.action2dict(method='@constant', value=np.nan)

df['inferred_reward_dt'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='inferred_reward_dt', intent_order=0)
builder.add_column_description(column_name='inferred_reward_dt', description="The timestamp associated with the inferred reward")

# %% [markdown]
# ------------------

# %%
builder.report_intent(stylise=False)
# Out:
#                  level order                intent  \
# 0        action_reward     0          get_category
# 1        action_reward     1   correlate_selection
# 2     action_reward_dt     0   correlate_selection
# 3       action_success     0          get_category
# 4          feedback_dt     0  correlate_categories
# 5          feedback_id     0          get_datetime
# 6   inferred_causation     0   correlate_selection
# 7     inferred_channel     0   correlate_selection
# 8      inferred_reward     0   correlate_selection
# 9   inferred_reward_dt     0   correlate_selection
# 10    intervention_cat     0  correlate_categories
# 11             plan_id     0      correlate_choice
# 12    reporting_system     0  correlate_categories
# 13         watch_start     0  correlate_categories
# 14         watch_start     1  correlate_categories
# 15          watch_stop     0  correlate_categories
# 16          watch_stop     1  correlate_categories
# 17           watchlist     0         frame_starter
#
#                                                                                                                                                                                                  parameters  \
# 0                                                                                                                                    [selection=[1, 0], relative_freq=[40, 1], column_name='action_reward']
# 1   [selection=[{'column': 'intervention_cat', 'condition': '@ == 3'}, {'column': 'action_success', 'condition': '@ == 0', 'logic': 'OR'}], action={'method': '@constant', 'value': 0}, default_action={...
# 2   [selection=[{'column': 'action_reward', 'condition': '@ == 1'}], action={'method': 'correlate_dates', 'header': 'feedback_dt', 'jitter': 3, 'jitter_units': 'h', 'jitter_freq': [1, 0]}, default_act...
# 3                                                                                                                                   [selection=[1, 0], relative_freq=[99, 1], column_name='action_success']
# 4   [header='intervention_cat', correlations=[1, 2, 3], actions={0: {'method': 'correlate_dates', 'header': 'watch_start', 'jitter': 3, 'jitter_units': 'D', 'jitter_freq': [0, 1]}, 1: {'method': 'corr...
# 5                                                                                                       [start=0, until=1, at_most=1, ordered='asc', date_format='%Y%m%d%H%M%S', column_name='feedback_id']
# 6   [selection=[{'column': 'inferred_reward', 'condition': '@ == 1'}], action={'method': 'get_number', 'from_value': 0, 'to_value': 1.0, 'precision': 2, 'relative_freq': [0.01, 0.01, 0.1, 1, 3, 2, 0.1...
# 7   [selection=[{'column': 'inferred_reward', 'condition': '@ == 1'}], action={'method': 'get_category', 'selection': ['BI systems', 'Claims', 'Remmitance', 'Contact Center Systems', 'Government', 'Ex...
# 8   [selection=[{'column': 'action_reward', 'condition': '@ == 1'}], action={'method': 'get_category', 'selection': [1, 0], 'relative_freq': [0.001, 1]}, default_action={'method': '@constant', 'value'...
# 9   [selection=[{'column': 'inferred_reward', 'condition': '@ == 1'}], action={'method': 'correlate_dates', 'header': 'action_reward_dt', 'offset': 1, 'jitter': 1, 'jitter_units': 'D', 'jitter_freq': ...
# 10  [header='intervention_id', correlations=['Outreach nurse contacts high flu risk member', 'Prompt member to call the nurseline for information about flu shots', 'Do nothing'], actions={0: 1, 1: 2, ...
# 11                                                                                                                              [header='plan_id', list_size=1, random_choice=False, column_name='plan_id']
# 12  [header='intervention_id', correlations=['Outreach nurse contacts high flu risk member', 'Prompt member to call the nurseline for information about flu shots', 'Do nothing'], actions={0: 'CSS', 1:...
# 13  [header='intervention_cat', correlations=[1, 2, 3], actions={0: {'method': 'get_datetime', 'start': -4, 'until': -3, 'ignore_time': True, 'date_format': '%Y-%m-%d %H:%M'}, 1: {'method': 'get_datet...
# 14  [header='intervention_cat', correlations=[1, 2, 3], actions={0: {'method': 'correlate_dates', 'header': 'watch_start', 'offset': {'hours': 8, 'minutes': 20}}, 1: {'method': 'correlate_dates', 'hea...
# 15  [header='intervention_cat', correlations=[1, 2, 3], actions={0: {'method': 'get_datetime', 'start': -1, 'until': 0, 'ignore_time': True, 'date_format': '%Y-%m-%d %H:%M'}, 1: {'method': 'get_dateti...
# 16  [header='intervention_cat', correlations=[1, 2, 3], actions={0: {'method': 'correlate_dates', 'header': 'watch_stop', 'offset': {'hours': -7, 'minutes': 45}}, 1: {'method': 'correlate_dates', 'hea...
# 17                                                                                                                                                          [canonical='feedback', column_name='watchlist']
#
#       creator
# 0   doatridge
# 1   doatridge
# 2   doatridge
# 3   doatridge
# 4   doatridge
# 5   doatridge
# 6   doatridge
# 7   doatridge
# 8   doatridge
# 9   doatridge
# 10  doatridge
# 11  doatridge
# 12  doatridge
# 13  doatridge
# 14  doatridge
# 15  doatridge
# 16  doatridge
# 17  doatridge

# %%
builder.canonical_report(df)
# Out:
# <style  type="text/css" >
#     #T_30932_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_30932_ .row_heading, .blank {
#           display: none;;
#     }#T_30932_row0_col0,#T_30932_row1_col0,#T_30932_row2_col0,#T_30932_row3_col0,#T_30932_row4_col0,#T_30932_row5_col0,#T_30932_row6_col0,#T_30932_row7_col0,#T_30932_row8_col0,#T_30932_row9_col0,#T_30932_row10_col0,#T_30932_row11_col0,#T_30932_row12_col0,#T_30932_row13_col0,#T_30932_row14_col0,#T_30932_row15_col0,#T_30932_row16_col0,#T_30932_row17_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_30932_row0_col1,#T_30932_row2_col1,#T_30932_row8_col1,#T_30932_row10_col1{
#             color:  #0f398a;
#         }#T_30932_row0_col2,#T_30932_row1_col2,#T_30932_row1_col3,#T_30932_row1_col6,#T_30932_row2_col2,#T_30932_row3_col2,#T_30932_row4_col2,#T_30932_row4_col3,#T_30932_row4_col4,#T_30932_row5_col2,#T_30932_row5_col3,#T_30932_row5_col6,#T_30932_row6_col2,#T_30932_row7_col2,#T_30932_row8_col2,#T_30932_row10_col2,#T_30932_row11_col2,#T_30932_row12_col2,#T_30932_row13_col2,#T_30932_row13_col3,#T_30932_row13_col6,#T_30932_row14_col2,#T_30932_row15_col2,#T_30932_row16_col2,#T_30932_row17_col2{
#             color:  black;
#         }#T_30932_row0_col3,#T_30932_row0_col4{
#             background-color:  #fcb499;
#             color:  black;
#         }#T_30932_row0_col6,#T_30932_row2_col6,#T_30932_row7_col6,#T_30932_row8_col6{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_30932_row1_col1,#T_30932_row4_col1,#T_30932_row9_col1,#T_30932_row16_col1,#T_30932_row17_col1{
#             color:  #790f8a;
#         }#T_30932_row1_col4,#T_30932_row5_col4,#T_30932_row6_col3,#T_30932_row6_col4,#T_30932_row7_col3,#T_30932_row7_col4,#T_30932_row8_col3,#T_30932_row8_col4,#T_30932_row9_col2,#T_30932_row9_col3,#T_30932_row9_col4,#T_30932_row13_col4,#T_30932_row15_col3,#T_30932_row15_col4,#T_30932_row15_col6{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_30932_row2_col3{
#             background-color:  #fb7858;
#             color:  white;
#         }#T_30932_row2_col4{
#             background-color:  #f7593f;
#             color:  white;
#         }#T_30932_row3_col3,#T_30932_row3_col4,#T_30932_row10_col3,#T_30932_row10_col4,#T_30932_row11_col3,#T_30932_row11_col4,#T_30932_row12_col3,#T_30932_row12_col4,#T_30932_row14_col3,#T_30932_row14_col4,#T_30932_row16_col3,#T_30932_row16_col4,#T_30932_row17_col3,#T_30932_row17_col4{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_30932_row3_col6,#T_30932_row6_col6,#T_30932_row9_col6,#T_30932_row10_col6,#T_30932_row11_col6,#T_30932_row12_col6,#T_30932_row14_col6,#T_30932_row16_col6,#T_30932_row17_col6{
#             background-color:  #84cc83;
#             color:  black;
#         }#T_30932_row4_col6{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_30932_row6_col1{
#             color:  #2f0f8a;
#         }</style><table id="T_30932_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (18)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_30932_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_30932_row0_col0" class="data row0 col0" >action_reward</td>
#                         <td id="T_30932_row0_col1" class="data row0 col1" >int64</td>
#                         <td id="T_30932_row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_30932_row0_col3" class="data row0 col3" >93.1%</td>
#                                 <td id="T_30932_row0_col5" class="data row0 col5" >1727</td>
#                         <td id="T_30932_row0_col6" class="data row0 col6" >2</td>
#                         <td id="T_30932_row0_col7" class="data row0 col7" >max=1 | min=0 | mean=0.93 | dominant=1</td>
#             </tr>
#             <tr>
#                         <th id="T_30932_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_30932_row1_col0" class="data row1 col0" >action_reward_dt</td>
#                         <td id="T_30932_row1_col1" class="data row1 col1" >datetime64[ns]</td>
#                         <td id="T_30932_row1_col2" class="data row1 col2" >6.9%</td>
#                         <td id="T_30932_row1_col3" class="data row1 col3" >6.9%</td>
#                                 <td id="T_30932_row1_col5" class="data row1 col5" >1727</td>
#                         <td id="T_30932_row1_col6" class="data row1 col6" >1526</td>
#                         <td id="T_30932_row1_col7" class="data row1 col7" >max=2021-03-10 12:02:21 | min=2021-03-08 06:50:06 | yr mean= 2021</td>
#             </tr>
#             <tr>
#                         <th id="T_30932_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_30932_row2_col0" class="data row2 col0" >action_success</td>
#                         <td id="T_30932_row2_col1" class="data row2 col1" >int64</td>
#                         <td id="T_30932_row2_col2" class="data row2 col2" >0.0%</td>
#                         <td id="T_30932_row2_col3" class="data row2 col3" >98.9%</td>
#                                 <td id="T_30932_row2_col5" class="data row2 col5" >1727</td>
#                         <td id="T_30932_row2_col6" class="data row2 col6" >2</td>
#                         <td id="T_30932_row2_col7" class="data row2 col7" >max=1 | min=0 | mean=0.99 | dominant=1</td>
#             </tr>
#             <tr>
#                         <th id="T_30932_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_30932_row3_col0" class="data row3 col0" >activation_id</td>
#                         <td id="T_30932_row3_col1" class="data row3 col1" >object</td>
#                         <td id="T_30932_row3_col2" class="data row3 col2" >2.5%</td>
#                         <td id="T_30932_row3_col3" class="data row3 col3" >83.4%</td>
#                                 <td id="T_30932_row3_col5" class="data row3 col5" >1727</td>
#                         <td id="T_30932_row3_col6" class="data row3 col6" >3</td>
#                         <td id="T_30932_row3_col7" class="data row3 col7" >Sample: 5d0001a7-b61d-4d73-83f7-071eabb6312e | 9d0ae5a5-7783-44ec-bcb7-618478f748a4</td>
#             </tr>
#             <tr>
#                         <th id="T_30932_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_30932_row4_col0" class="data row4 col0" >feedback_dt</td>
#                         <td id="T_30932_row4_col1" class="data row4 col1" >datetime64[ns]</td>
#                         <td id="T_30932_row4_col2" class="data row4 col2" >0.0%</td>
#                         <td id="T_30932_row4_col3" class="data row4 col3" >42.8%</td>
#                                 <td id="T_30932_row4_col5" class="data row4 col5" >1727</td>
#                         <td id="T_30932_row4_col6" class="data row4 col6" >5</td>
#                         <td id="T_30932_row4_col7" class="data row4 col7" >max=2021-03-10 12:03:00 | min=2021-03-08 08:20:00 | yr mean= 2021</td>
#             </tr>
#             <tr>
#                         <th id="T_30932_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_30932_row5_col0" class="data row5 col0" >feedback_id</td>
#                         <td id="T_30932_row5_col1" class="data row5 col1" >object</td>
#                         <td id="T_30932_row5_col2" class="data row5 col2" >0.0%</td>
#                         <td id="T_30932_row5_col3" class="data row5 col3" >0.1%</td>

# %%
tools.run_intent_pipeline(simulate=True)
# Out:
#                 column order                method
# 0            watchlist     0         frame_starter
# 1          feedback_id     0          get_datetime
# 2       action_success     0          get_category
# 3              plan_id     0      correlate_choice
# 4     intervention_cat     0  correlate_categories
# 5          watch_start     0  correlate_categories
# 6          watch_start     1  correlate_categories
# 7           watch_stop     0  correlate_categories
# 8           watch_stop     1  correlate_categories
# 9          feedback_dt     0  correlate_categories
# 10       action_reward     0          get_category
# 11       action_reward     1   correlate_selection
# 12    action_reward_dt     0   correlate_selection
# 13    reporting_system     0  correlate_categories
# 14     inferred_reward     0   correlate_selection
# 15  inferred_causation     0   correlate_selection
# 16    inferred_channel     0   correlate_selection
# 17  inferred_reward_dt     0   correlate_selection

# %%
builder.run_component_pipeline(canonical='feedback')

# %%
builder.report_column_catalog()
# Out:
# <style  type="text/css" >
#     #T_ac7ff_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_ac7ff_ .row_heading, .blank {
#           display: none;;
#     }#T_ac7ff_row0_col0,#T_ac7ff_row1_col0,#T_ac7ff_row2_col0,#T_ac7ff_row3_col0,#T_ac7ff_row4_col0,#T_ac7ff_row5_col0,#T_ac7ff_row6_col0,#T_ac7ff_row7_col0,#T_ac7ff_row8_col0,#T_ac7ff_row9_col0,#T_ac7ff_row10_col0,#T_ac7ff_row11_col0,#T_ac7ff_row12_col0,#T_ac7ff_row13_col0,#T_ac7ff_row14_col0{
#             text-align:  left;
#             font-weight:  bold;
#         }#T_ac7ff_row0_col1,#T_ac7ff_row1_col1,#T_ac7ff_row2_col1,#T_ac7ff_row3_col1,#T_ac7ff_row4_col1,#T_ac7ff_row5_col1,#T_ac7ff_row6_col1,#T_ac7ff_row7_col1,#T_ac7ff_row8_col1,#T_ac7ff_row9_col1,#T_ac7ff_row10_col1,#T_ac7ff_row11_col1,#T_ac7ff_row12_col1,#T_ac7ff_row13_col1,#T_ac7ff_row14_col1{
#             text-align:  left;
#         }</style><table id="T_ac7ff_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >column_name</th>        <th class="col_heading level0 col1" >description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ac7ff_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ac7ff_row0_col0" class="data row0 col0" >action_reward</td>
#                         <td id="T_ac7ff_row0_col1" class="data row0 col1" >If the member has interacted with the intervention, e.g. contacted, enacted upon an action or read a notification</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ac7ff_row1_col0" class="data row1 col0" >action_reward_dt</td>
#                         <td id="T_ac7ff_row1_col1" class="data row1 col1" >a recorded date time when the recorded interaction occured</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ac7ff_row2_col0" class="data row2 col0" >action_success</td>
#                         <td id="T_ac7ff_row2_col1" class="data row2 col1" >If the profile has their permissions set favourably for this intervention</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ac7ff_row3_col0" class="data row3 col0" >feedback_dt</td>
#                         <td id="T_ac7ff_row3_col1" class="data row3 col1" >The date when feedback was recieved</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ac7ff_row4_col0" class="data row4 col0" >feedback_id</td>
#                         <td id="T_ac7ff_row4_col1" class="data row4 col1" >a unique reference id from the feedback system unique across all feeback batches</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ac7ff_row5_col0" class="data row5 col0" >inferred_causation</td>
#                         <td id="T_ac7ff_row5_col1" class="data row5 col1" >a confidence value of the inferred causation of the action to the reward</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ac7ff_row6_col0" class="data row6 col0" >inferred_channel</td>
#                         <td id="T_ac7ff_row6_col1" class="data row6 col1" >The channel from which the observation came</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ac7ff_row7_col0" class="data row7 col0" >inferred_reward</td>
#                         <td id="T_ac7ff_row7_col1" class="data row7 col1" >a signal to indicate the </td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ac7ff_row8_col0" class="data row8 col0" >inferred_reward_dt</td>
#                         <td id="T_ac7ff_row8_col1" class="data row8 col1" >The timestamp associated with the inferred reward</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ac7ff_row9_col0" class="data row9 col0" >intervention_cat</td>
#                         <td id="T_ac7ff_row9_col1" class="data row9 col1" >for clarity changing the intervention_id string to a numberic category</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_ac7ff_row10_col0" class="data row10 col0" >plan_id</td>
#                         <td id="T_ac7ff_row10_col1" class="data row10 col1" >temporary modification of the Plan id, taking only one id from the list</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_ac7ff_row11_col0" class="data row11 col0" >reporting_system</td>
#                         <td id="T_ac7ff_row11_col1" class="data row11 col1" >The system that reported the feedback</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_ac7ff_row12_col0" class="data row12 col0" >watch_start</td>
#                         <td id="T_ac7ff_row12_col1" class="data row12 col1" >modify the watch start to place it in the past</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_ac7ff_row13_col0" class="data row13 col0" >watch_stop</td>
#                         <td id="T_ac7ff_row13_col1" class="data row13 col1" >modify the watch end after the watch_start</td>
#             </tr>
#             <tr>
#                         <th id="T_ac7ff_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_ac7ff_row14_col0" class="data row14 col0" >watchlist</td>
#                         <td id="T_ac7ff_row14_col1" class="data row14 col1" >extracted watchlist from the plan executor</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# -------------------------
# -------------------------
# ## Intervention Feedback

# %%
tr = Transition.from_env('feedback')

# %%
tr.pm.reset_intents()
tr.pm_persist()

# %%
df = tr.load_source_canonical()

# %%
df = tr.cleaners.auto_clean_header(df, rename_map={'member_id': 'profile_id'})
df = tr.cleaners.auto_transition(df)
df = tr.cleaners.to_date_type(df, regex=['_dt'])
df = tr.cleaners.to_remove(df, regex=['watch_', 'intervention_cat'])

# %%
tr.upload_attributes(builder.report_column_catalog(stylise=False), label_key='column_name', text_key='description', constraints=list(df.columns))

# %% [markdown]
# ## Run the Pipeline  save the Schema and show the Schema Report

# %%
# run the pipeline
tr.run_component_pipeline()

# report the canonical
tr.canonical_report(df)
# Out:
# <style  type="text/css" >
#     #T_95595_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_95595_ .row_heading, .blank {
#           display: none;;
#     }#T_95595_row0_col0,#T_95595_row1_col0,#T_95595_row2_col0,#T_95595_row3_col0,#T_95595_row4_col0,#T_95595_row5_col0,#T_95595_row6_col0,#T_95595_row7_col0,#T_95595_row8_col0,#T_95595_row9_col0,#T_95595_row10_col0,#T_95595_row11_col0,#T_95595_row12_col0,#T_95595_row13_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_95595_row0_col1,#T_95595_row2_col1,#T_95595_row8_col1{
#             color:  #08488e;
#         }#T_95595_row0_col2,#T_95595_row1_col2,#T_95595_row1_col3,#T_95595_row1_col6,#T_95595_row2_col2,#T_95595_row3_col2,#T_95595_row4_col2,#T_95595_row4_col3,#T_95595_row4_col4,#T_95595_row5_col2,#T_95595_row5_col3,#T_95595_row5_col6,#T_95595_row6_col2,#T_95595_row7_col2,#T_95595_row8_col2,#T_95595_row10_col2,#T_95595_row11_col2,#T_95595_row12_col2,#T_95595_row12_col3,#T_95595_row12_col6,#T_95595_row13_col2{
#             color:  black;
#         }#T_95595_row0_col3,#T_95595_row0_col4{
#             background-color:  #fcb499;
#             color:  black;
#         }#T_95595_row0_col6,#T_95595_row2_col6,#T_95595_row6_col6,#T_95595_row7_col6,#T_95595_row8_col6,#T_95595_row9_col6{
#             background-color:  #a1cbe2;
#             color:  black;
#         }#T_95595_row1_col1,#T_95595_row4_col1,#T_95595_row9_col1{
#             color:  #790f8a;
#         }#T_95595_row1_col4,#T_95595_row5_col4,#T_95595_row6_col3,#T_95595_row6_col4,#T_95595_row7_col3,#T_95595_row7_col4,#T_95595_row8_col3,#T_95595_row8_col4,#T_95595_row9_col2,#T_95595_row9_col3,#T_95595_row9_col4,#T_95595_row12_col4{
#             background-color:  #ec382b;
#             color:  white;
#         }#T_95595_row2_col3{
#             background-color:  #fb7858;
#             color:  white;
#         }#T_95595_row2_col4{
#             background-color:  #f7593f;
#             color:  white;
#         }#T_95595_row3_col1,#T_95595_row6_col1,#T_95595_row7_col1,#T_95595_row10_col1,#T_95595_row11_col1,#T_95595_row13_col1{
#             color:  #208a0f;
#         }#T_95595_row3_col3,#T_95595_row3_col4,#T_95595_row10_col3,#T_95595_row10_col4,#T_95595_row11_col3,#T_95595_row11_col4,#T_95595_row13_col3,#T_95595_row13_col4{
#             background-color:  #ffede5;
#             color:  black;
#         }#T_95595_row3_col6,#T_95595_row10_col6,#T_95595_row11_col6,#T_95595_row13_col6{
#             background-color:  #84cc83;
#             color:  black;
#         }#T_95595_row4_col6{
#             background-color:  #a4da9e;
#             color:  black;
#         }#T_95595_row5_col1,#T_95595_row12_col1{
#             color:  #0f398a;
#         }</style><table id="T_95595_" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (14)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_95595_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_95595_row0_col0" class="data row0 col0" >action_reward</td>
#                         <td id="T_95595_row0_col1" class="data row0 col1" >bool</td>
#                         <td id="T_95595_row0_col2" class="data row0 col2" >0.0%</td>
#                         <td id="T_95595_row0_col3" class="data row0 col3" >94.0%</td>
#                                 <td id="T_95595_row0_col5" class="data row0 col5" >1727</td>
#                         <td id="T_95595_row0_col6" class="data row0 col6" >2</td>
#                         <td id="T_95595_row0_col7" class="data row0 col7" >False | True</td>
#             </tr>
#             <tr>
#                         <th id="T_95595_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_95595_row1_col0" class="data row1 col0" >action_reward_dt</td>
#                         <td id="T_95595_row1_col1" class="data row1 col1" >datetime64[ns]</td>
#                         <td id="T_95595_row1_col2" class="data row1 col2" >6.0%</td>
#                         <td id="T_95595_row1_col3" class="data row1 col3" >6.0%</td>
#                                 <td id="T_95595_row1_col5" class="data row1 col5" >1727</td>
#                         <td id="T_95595_row1_col6" class="data row1 col6" >1532</td>
#                         <td id="T_95595_row1_col7" class="data row1 col7" >max=2021-03-10 12:02:40 | min=2021-03-08 06:50:00 | yr mean= 2021</td>
#             </tr>
#             <tr>
#                         <th id="T_95595_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_95595_row2_col0" class="data row2 col0" >action_success</td>
#                         <td id="T_95595_row2_col1" class="data row2 col1" >bool</td>
#                         <td id="T_95595_row2_col2" class="data row2 col2" >0.0%</td>
#                         <td id="T_95595_row2_col3" class="data row2 col3" >98.9%</td>
#                                 <td id="T_95595_row2_col5" class="data row2 col5" >1727</td>
#                         <td id="T_95595_row2_col6" class="data row2 col6" >2</td>
#                         <td id="T_95595_row2_col7" class="data row2 col7" >True | False</td>
#             </tr>
#             <tr>
#                         <th id="T_95595_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_95595_row3_col0" class="data row3 col0" >activation_id</td>
#                         <td id="T_95595_row3_col1" class="data row3 col1" >category</td>
#                         <td id="T_95595_row3_col2" class="data row3 col2" >0.0%</td>
#                         <td id="T_95595_row3_col3" class="data row3 col3" >83.4%</td>
#                                 <td id="T_95595_row3_col5" class="data row3 col5" >1727</td>
#                         <td id="T_95595_row3_col6" class="data row3 col6" >3</td>
#                         <td id="T_95595_row3_col7" class="data row3 col7" >Sample: 5d0001a7-b61d-4d73-83f7-071eabb6312e | 9d0ae5a5-7783-44ec-bcb7-618478f748a4 | None</td>
#             </tr>
#             <tr>
#                         <th id="T_95595_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_95595_row4_col0" class="data row4 col0" >feedback_dt</td>
#                         <td id="T_95595_row4_col1" class="data row4 col1" >datetime64[ns]</td>
#                         <td id="T_95595_row4_col2" class="data row4 col2" >0.0%</td>
#                         <td id="T_95595_row4_col3" class="data row4 col3" >42.2%</td>
#                                 <td id="T_95595_row4_col5" class="data row4 col5" >1727</td>
#                         <td id="T_95595_row4_col6" class="data row4 col6" >5</td>
#                         <td id="T_95595_row4_col7" class="data row4 col7" >max=2021-03-10 12:03:00 | min=2021-03-08 08:20:00 | yr mean= 2021</td>
#             </tr>
#             <tr>
#                         <th id="T_95595_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_95595_row5_col0" class="data row5 col0" >feedback_id</td>
#                         <td id="T_95595_row5_col1" class="data row5 col1" >int64</td>
#                         <td id="T_95595_row5_col2" class="data row5 col2" >0.0%</td>
#                         <td id="T_95595_row5_col3" class="data row5 col3" >0.1%</td>
#                                 <td id="T_95595_row5_col5" class="data row5 col5" >1727</td>
#                         <td id="T_95595_row5_col6" class="data row5 col6" >1727</td>
#                         <td id="T_95595_row5_col7" class="data row5 col7" >max=20210313123659 | min=20210312123814 | mean=20210312640857.9 | dominant=[20210312123814, 202103121

# %%
tr.report_attributes(df)
# Out:
# <style  type="text/css" >
#     #T_dda1c_ th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_dda1c_ .row_heading, .blank {
#           display: none;;
#     }#T_dda1c_row0_col0,#T_dda1c_row1_col0,#T_dda1c_row2_col0,#T_dda1c_row3_col0,#T_dda1c_row4_col0,#T_dda1c_row5_col0,#T_dda1c_row6_col0,#T_dda1c_row7_col0,#T_dda1c_row8_col0,#T_dda1c_row9_col0,#T_dda1c_row10_col0,#T_dda1c_row11_col0,#T_dda1c_row12_col0,#T_dda1c_row13_col0{
#             font-weight:  bold;
#             font-size:  120%;
#         }#T_dda1c_row0_col1,#T_dda1c_row2_col1,#T_dda1c_row8_col1{
#             color:  #08488e;
#         }#T_dda1c_row0_col2,#T_dda1c_row1_col2,#T_dda1c_row2_col2,#T_dda1c_row3_col2,#T_dda1c_row4_col2,#T_dda1c_row5_col2,#T_dda1c_row6_col2,#T_dda1c_row7_col2,#T_dda1c_row8_col2,#T_dda1c_row9_col2,#T_dda1c_row10_col2,#T_dda1c_row11_col2,#T_dda1c_row12_col2,#T_dda1c_row13_col2{
#             text-align:  left;
#         }#T_dda1c_row1_col1,#T_dda1c_row4_col1,#T_dda1c_row9_col1{
#             color:  #790f8a;
#         }#T_dda1c_row3_col1,#T_dda1c_row6_col1,#T_dda1c_row7_col1,#T_dda1c_row10_col1,#T_dda1c_row11_col1,#T_dda1c_row13_col1{
#             color:  #208a0f;
#         }#T_dda1c_row5_col1,#T_dda1c_row12_col1{
#             color:  #0f398a;
#         }</style><table id="T_dda1c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (14)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dda1c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dda1c_row0_col0" class="data row0 col0" >action_reward</td>
#                         <td id="T_dda1c_row0_col1" class="data row0 col1" >bool</td>
#                         <td id="T_dda1c_row0_col2" class="data row0 col2" >If the member has interacted with the intervention, e.g. contacted, enacted upon an action or read a notification</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dda1c_row1_col0" class="data row1 col0" >action_reward_dt</td>
#                         <td id="T_dda1c_row1_col1" class="data row1 col1" >datetime64[ns]</td>
#                         <td id="T_dda1c_row1_col2" class="data row1 col2" >a recorded date time when the recorded interaction occured</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dda1c_row2_col0" class="data row2 col0" >action_success</td>
#                         <td id="T_dda1c_row2_col1" class="data row2 col1" >bool</td>
#                         <td id="T_dda1c_row2_col2" class="data row2 col2" >If the profile has their permissions set favourably for this intervention</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dda1c_row3_col0" class="data row3 col0" >activation_id</td>
#                         <td id="T_dda1c_row3_col1" class="data row3 col1" >category</td>
#                         <td id="T_dda1c_row3_col2" class="data row3 col2" ></td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dda1c_row4_col0" class="data row4 col0" >feedback_dt</td>
#                         <td id="T_dda1c_row4_col1" class="data row4 col1" >datetime64[ns]</td>
#                         <td id="T_dda1c_row4_col2" class="data row4 col2" >The date when feedback was recieved</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dda1c_row5_col0" class="data row5 col0" >feedback_id</td>
#                         <td id="T_dda1c_row5_col1" class="data row5 col1" >int64</td>
#                         <td id="T_dda1c_row5_col2" class="data row5 col2" >a unique reference id from the feedback system unique across all feeback batches</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dda1c_row6_col0" class="data row6 col0" >inferred_causation</td>
#                         <td id="T_dda1c_row6_col1" class="data row6 col1" >category</td>
#                         <td id="T_dda1c_row6_col2" class="data row6 col2" >a confidence value of the inferred causation of the action to the reward</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dda1c_row7_col0" class="data row7 col0" >inferred_channel</td>
#                         <td id="T_dda1c_row7_col1" class="data row7 col1" >category</td>
#                         <td id="T_dda1c_row7_col2" class="data row7 col2" >The channel from which the observation came</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_dda1c_row8_col0" class="data row8 col0" >inferred_reward</td>
#                         <td id="T_dda1c_row8_col1" class="data row8 col1" >bool</td>
#                         <td id="T_dda1c_row8_col2" class="data row8 col2" >a signal to indicate the </td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_dda1c_row9_col0" class="data row9 col0" >inferred_reward_dt</td>
#                         <td id="T_dda1c_row9_col1" class="data row9 col1" >datetime64[ns]</td>
#                         <td id="T_dda1c_row9_col2" class="data row9 col2" >The timestamp associated with the inferred reward</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_dda1c_row10_col0" class="data row10 col0" >intervention_id</td>
#                         <td id="T_dda1c_row10_col1" class="data row10 col1" >category</td>
#                         <td id="T_dda1c_row10_col2" class="data row10 col2" ></td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_dda1c_row11_col0" class="data row11 col0" >plan_id</td>
#                         <td id="T_dda1c_row11_col1" class="data row11 col1" >category</td>
#                         <td id="T_dda1c_row11_col2" class="data row11 col2" >temporary modification of the Plan id, taking only one id from the list</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_dda1c_row12_col0" class="data row12 col0" >profile_id</td>
#                         <td id="T_dda1c_row12_col1" class="data row12 col1" >int64</td>
#                         <td id="T_dda1c_row12_col2" class="data row12 col2" ></td>
#             </tr>
#             <tr>
#                         <th id="T_dda1c_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_dda1c_row13_col0" class="data row13 col0" >reporting_system</td>
#                         <td id="T_dda1c_row13_col1" class="data row13 col1" >category</td>
#                         <td id="T_dda1c_row13_col2" class="data row13 col2" >The system that reported the feedback</td>
#             </tr>
#     </tbody></table>
